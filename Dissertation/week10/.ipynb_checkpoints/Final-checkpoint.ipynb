# %% [markdown]
# # 导入

# %%
import pandas as pd
import geopandas as gpd
from shapely import wkt
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from scipy.spatial import distance_matrix
from sklearn.preprocessing import StandardScaler
import torch
import torch.nn.functional as F
from torch_geometric.nn import GINConv, global_add_pool
from torch_geometric.utils import from_networkx
from statsmodels.stats.outliers_influence import variance_inflation_factor
import random
import itertools
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# 读取CSV文件并创建GeoDataFrame
csv_file = 'LondonLSOAs.csv'
df = pd.read_csv(csv_file)

# 创建几何对象（假设geometry列包含WKT格式的多边形数据）
gdf = gpd.GeoDataFrame(df, geometry=gpd.GeoSeries.from_wkt(df['geometry']))

# 设置坐标系 (假设是WGS84坐标系)
gdf.set_crs(epsg=4326, inplace=True)

# 计算每个LSOA的几何中心点
gdf['geo_centroid'] = gdf.centroid

# 计算相邻关系
neighbors = gpd.sjoin(gdf, gdf, how='left', predicate='intersects')

# 手动处理索引
neighbors = neighbors[neighbors.index != neighbors.index_right]

# 构建邻接矩阵
G = nx.Graph()

# 添加节点
for idx, row in gdf.iterrows():
    G.add_node(idx, pos=(row.geo_centroid.x, row.geo_centroid.y))

# 添加边，根据相邻关系
for idx, row in neighbors.iterrows():
    G.add_edge(row.name, row['index_right'], weight=1)

# 可视化邻接关系
pos = nx.get_node_attributes(G, 'pos')
plt.figure(figsize=(10, 10))
nx.draw(G, pos, node_size=10, node_color='blue', edge_color='grey', alpha=0.5)
plt.title("Adjacency Network")
plt.show()
# Out:
# C:\Users\0\AppData\Local\Temp\ipykernel_10580\612648604.py:12: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf['geo_centroid'] = gdf.centroid

# %%
# 读取CSV文件并创建GeoDataFrame
csv_file = 'LondonLSOAs.csv'
df = pd.read_csv(csv_file)

# 创建几何对象（假设geometry列包含WKT格式的多边形数据）
gdf = gpd.GeoDataFrame(df, geometry=gpd.GeoSeries.from_wkt(df['geometry']))

# 设置坐标系 (假设是WGS84坐标系)
gdf.set_crs(epsg=4326, inplace=True)

# 固定选取的变量
fixed_columns = [
    'c_percent Aged 10 to 14 years',
    'c_percent Aged 15 to 19 years',
    'c_percent Aged 20 to 24 years',
    'c_percent Aged 25 to 29 years',
    'c_percent Aged 30 to 34 years',
    'c_percent Aged 35 to 39 years',
    'c_percent Aged 40 to 44 years',
    'c_percent Aged 65 to 69 years',
    'c_percent Aged 70 to 74 years',
    'c_percent Aged 75 to 79 years',
    'c_percent Aged 80 to 84 years',
    'c_percent Aged 85 years and over',
    'c_percent mixed',
    'c_percent white',
    'c_percent 2. Professional occupations',
    'c_pop_density',
    'e_NO2',
    'e_ndvi',
    'e_water',
    'e_trees',
    'e_grass',
    'e_bare',
    'c_percent asian',
    'c_percent black',
    'c_percent buddhist',
    'c_percent muslim',
    'c_percent no central heating',
    'c_percent communal heating',
    'c_percent TFW less than 2km',
    'c_percent 49 or more hours worked',
    'c_percent commute on foot',
    'c_percent commute metro rail',
    'c_percent commute bus',
    'c_percent commute bicycle',
    'c_percent student moved to address',
    'c_percent occupancy rating bedrooms -2',
    'c_percent occupancy rating bedrooms -1',
    # 'c_percent occupancy rating rooms -1',
    'c_percent 10 years or more',
    'c_percent 2 years or more but less than 5 years',
    'c_percent 5 years or more but less than 10 years',
    'c_percent married or in a registered civil partnership married same sex',
    'c_percent married or in a registered civil partnership in a registered civil partnership',
    # 'c_percent married or in a registered civil partnership in a registered civil partnership same sex',
    'c_percent separated but still legally married or still legally in a civil partnership separated but still in a registered civil partnership',
    'c_percent divorced or civil partnership dissolved formerly in a civil partnership now legally dissolved',
    'c_percent   cannot speak english well',
    'c_percent   cannot speak english',
    'c_percent households deprived in four dimensions'
]

# 提取固定变量
fixed_features = gdf[fixed_columns].apply(pd.to_numeric, errors='coerce')

# 使用邻接节点的均值填充空值
for i, row in fixed_features.iterrows():
    for col in fixed_columns:
        if pd.isna(row[col]):
            neighbor_indices = list(G.neighbors(i))
            if neighbor_indices:  # 确保有邻居
                neighbor_values = fixed_features.iloc[neighbor_indices][col]
                mean_value = neighbor_values.mean()
                if pd.isna(mean_value):
                    mean_value = fixed_features[col].mean()  # 如果邻居的均值还是nan，使用全局均值填充
                fixed_features.at[i, col] = mean_value
            else:
                fixed_features.at[i, col] = fixed_features[col].mean()  # 如果没有邻居，使用全局均值填充

# 再次检查是否有任何nan值
print("Remaining NaN count:", fixed_features.isna().sum().sum())

# 计算VIF
def calculate_vif(df):
    vif = pd.DataFrame()
    vif["Variable"] = df.columns
    vif["VIF"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
    return vif

vif_df = calculate_vif(fixed_features)
print(vif_df)

# 进行标准化
scaler = StandardScaler()
final_features_scaled = scaler.fit_transform(fixed_features)
final_features_tensor = torch.tensor(final_features_scaled, dtype=torch.float)

# 准备目标变量
target_column = 'o_depression_quantity_per_capita'
target = gdf[target_column].apply(pd.to_numeric, errors='coerce').fillna(0)
targets = torch.tensor(target.values, dtype=torch.float).unsqueeze(1)  # 添加维度以匹配模型输出

# 将 NetworkX 图转换为 PyTorch Geometric 数据
from torch_geometric.utils import from_networkx
data = from_networkx(G)
data.x = final_features_tensor
data.y = targets
# Out:
# Remaining NaN count: 0
#                                              Variable         VIF
# 0                       c_percent Aged 10 to 14 years   47.337738
# 1                       c_percent Aged 15 to 19 years   17.964352
# 2                       c_percent Aged 20 to 24 years   35.844044
# 3                       c_percent Aged 25 to 29 years   37.354234
# 4                       c_percent Aged 30 to 34 years   58.088410
# 5                       c_percent Aged 35 to 39 years   73.285812
# 6                       c_percent Aged 40 to 44 years   73.637442
# 7                       c_percent Aged 65 to 69 years   35.718904
# 8                       c_percent Aged 70 to 74 years   34.047895
# 9                       c_percent Aged 75 to 79 years   26.720948
# 10                      c_percent Aged 80 to 84 years   19.927258
# 11                   c_percent Aged 85 years and over   10.234138
# 12                                    c_percent mixed   21.919998
# 13                                    c_percent white  345.064296
# 14              c_percent 2. Professional occupations   52.099970
# 15                                      c_pop_density    6.512723
# 16                                              e_NO2  928.671113
# 17                                             e_ndvi   78.283933
# 18                                            e_water    5.980936
# 19                                            e_trees    5.899178
# 20                                            e_grass    5.457379
# 21                                             e_bare   25.357267
# 22                                    c_percent asian   55.764007
# 23                                    c_percent black   33.269641
# 24                                 c_percent buddhist    3.249210
# 25                                   c_percent muslim   12.721599
# 26                       c_percent no central heating    8.300637
# 27                         c_percent communal heating    1.994387
# 28                        c_percent TFW less than 2km   33.181838
# 29                  c_percent 49 or more hours worked   28.721788
# 30                          c_percent commute on foot   31.219556
# 31                       c_percent commute metro rail   10.423055
# 32                              c_percent commute bus   18.976050
# 33                          c_percent commute bicycle    8.277014
# 34                 c_percent student moved to address    5.606390
# 35             c_percent occupancy rating bedrooms -2    8.125733
# 36             c_percent occupancy rating bedrooms -1   28.588216
# 37                         c_percent 10 years or more   69.305519
# 38    c_percent 2 years or more but less than 5 years   20.779049
# 39   c_percent 5 years or more but less than 10 years   29.108717
# 40  c_percent married or in a registered civil par...    3.101510
# 41  c_percent married or in a registered civil par...    2.901952
# 42  c_percent separated but still legally married ...    1.191993
# 43  c_percent divorced or civil partnership dissol...    1.588238
# 44              c_percent   cannot speak english well   22.908292
# 45                   c_percent   cannot speak english    7.079138
# 46   c_percent households deprived in four dimensions    2.527470

# %% [markdown]
# # 基础模型

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GATv2Conv
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import random
import itertools
import matplotlib.pyplot as plt
from torch_geometric.explain import Explainer
from torch_geometric.utils import k_hop_subgraph
from tqdm import tqdm

# 定义GATv2模型
class GATv2(torch.nn.Module):
    def __init__(self, in_channels, hidden1, hidden2, out_channels, dropout):
        super(GATv2, self).__init__()
        self.conv1 = GATv2Conv(in_channels, hidden1, heads=1)
        self.conv2 = GATv2Conv(hidden1, hidden2, heads=1)
        self.fc1 = torch.nn.Linear(hidden2, out_channels)
        self.dropout = dropout

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)  # Dropout
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)  # Dropout
        x = self.fc1(x)
        return x

def train(model, optimizer, data):
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index)
    loss = F.mse_loss(out, data.y)
    loss.backward()
    optimizer.step()
    return loss.item()

# 假设你已经有一个数据对象 data
# data = ...

# 定义超参数空间
param_space = {
    'lr': [0.001, 0.005, 0.01],
    'weight_decay': [5e-4, 1e-3, 5e-3],
    'hidden1': [32, 64, 128],
    'hidden2': [16, 32, 64],
    'dropout': [0.3, 0.5, 0.7],
    'num_epochs': [200]
}

# 随机搜索超参数
num_samples = 50  # 选择搜索的参数组合数量
random_params = [dict(zip(param_space, v)) for v in random.sample(list(itertools.product(*param_space.values())), num_samples)]

best_loss = float('inf')
best_params = None

for params in random_params:
    model = GATv2(
        in_channels=data.x.shape[1], 
        hidden1=params['hidden1'], 
        hidden2=params['hidden2'], 
        out_channels=data.y.shape[1], 
        dropout=params['dropout']
    )
    optimizer = torch.optim.Adam(model.parameters(), lr=params['lr'], weight_decay=params['weight_decay'])

    losses = []
    for epoch in range(params['num_epochs']):
        loss = train(model, optimizer, data)
        losses.append(loss)

    if losses[-1] < best_loss:
        best_loss = losses[-1]
        best_params = params

print(f'Best params: {best_params}, Best loss: {best_loss:.4f}')

# 使用最佳超参数重新训练模型
model = GATv2(
    in_channels=data.x.shape[1], 
    hidden1=best_params['hidden1'], 
    hidden2=best_params['hidden2'], 
    out_channels=data.y.shape[1], 
    dropout=best_params['dropout']
)
optimizer = torch.optim.Adam(model.parameters(), lr=best_params['lr'], weight_decay=best_params['weight_decay'])

losses = []
for epoch in range(best_params['num_epochs']):
    loss = train(model, optimizer, data)
    losses.append(loss)

# 测试模型并计算评估指标
model.eval()
with torch.no_grad():
    pred = model(data.x, data.edge_index)
    residuals = data.y - pred

# 计算评估指标
y_true = data.y.detach().numpy()
y_pred = pred.detach().numpy()

mse = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_true, y_pred)
r2 = r2_score(y_true, y_pred)

print(f'MSE: {mse:.4f}')
print(f'RMSE: {rmse:.4f}')
print(f'MAE: {mae:.4f}')
print(f'R²: {r2:.4f}')

# 可视化残差
plt.figure(figsize=(10, 5))
plt.hist(residuals.detach().numpy(), bins=50, alpha=0.75)
plt.xlabel('Residual')
plt.ylabel('Frequency')
plt.title('Histogram of Residuals')
plt.show()
# Out:
# Best params: {'lr': 0.01, 'weight_decay': 0.0005, 'hidden1': 64, 'hidden2': 32, 'dropout': 0.3, 'num_epochs': 200}, Best loss: 21.1216
# MSE: 20.9209
# RMSE: 4.5739
# MAE: 3.4991
# R²: 0.7490

# %%
import torch
from torch_geometric.utils import k_hop_subgraph
from sklearn.model_selection import KFold
import numpy as np

# 定义划分子图的函数
def create_subgraph(data, train_idx, test_idx, num_hops):
    train_idx = torch.tensor(train_idx, dtype=torch.long, device=data.edge_index.device)
    test_idx = torch.tensor(test_idx, dtype=torch.long, device=data.edge_index.device)
    
    # 获取训练集子图，包含 train_idx 节点以及 num_hops 范围内的邻居
    train_subgraph = k_hop_subgraph(train_idx, num_hops, data.edge_index, relabel_nodes=True)
    train_edge_index, train_x, train_y = train_subgraph[1], data.x[train_subgraph[0]], data.y[train_subgraph[0]]
    
    # 获取测试集子图，包含 test_idx 节点以及 num_hops 范围内的邻居
    test_subgraph = k_hop_subgraph(test_idx, num_hops, data.edge_index, relabel_nodes=True)
    test_edge_index, test_x, test_y = test_subgraph[1], data.x[test_subgraph[0]], data.y[test_subgraph[0]]
    
    return (train_x, train_edge_index, train_y), (test_x, test_edge_index, test_y)

# 定义K-Fold交叉验证
def k_fold_cross_validation(data, k=10, num_hops=2):
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    results = []

    all_indices = np.arange(data.num_nodes)
    
    for train_idx, test_idx in kf.split(all_indices):
        (train_x, train_edge_index, train_y), (test_x, test_edge_index, test_y) = create_subgraph(data, train_idx, test_idx, num_hops)
        
        # 重新初始化模型和优化器
        model = GATv2(
            in_channels=train_x.shape[1], 
            hidden1=best_params['hidden1'], 
            hidden2=best_params['hidden2'], 
            out_channels=train_y.shape[1], 
            dropout=best_params['dropout']
        )
        optimizer = torch.optim.Adam(model.parameters(), lr=best_params['lr'], weight_decay=best_params['weight_decay'])
        
        # 训练模型
        model.train()
        for epoch in range(best_params['num_epochs']):
            optimizer.zero_grad()
            out = model(train_x, train_edge_index)
            loss = F.mse_loss(out, train_y)
            loss.backward()
            optimizer.step()
        
        # 测试模型
        model.eval()
        with torch.no_grad():
            pred = model(test_x, test_edge_index)
            y_true = test_y.numpy()
            y_pred = pred.numpy()
            
            mse = mean_squared_error(y_true, y_pred)
            rmse = np.sqrt(mse)
            mae = mean_absolute_error(y_true, y_pred)
            r2 = r2_score(y_true, y_pred)
        
        results.append((mse, rmse, mae, r2))
    
    return results

# 假设你已经有一个数据对象 data
# data = ...

# 使用最佳超参数进行K-Fold交叉验证
results = k_fold_cross_validation(data)

# 打印K-Fold结果
for fold, (mse, rmse, mae, r2) in enumerate(results):
    print(f'Fold {fold + 1} - MSE: {mse:.4f}, RMSE: {rmse:.4f}, MAE: {mae:.4f}, R²: {r2:.4f}')

# 计算平均结果
avg_results = np.mean(results, axis=0)
print(f'Average - MSE: {avg_results[0]:.4f}, RMSE: {avg_results[1]:.4f}, MAE: {avg_results[2]:.4f}, R²: {avg_results[3]:.4f}')
# Out:
# Fold 1 - MSE: 19.5913, RMSE: 4.4262, MAE: 3.3560, R²: 0.7657
# Fold 2 - MSE: 16.9188, RMSE: 4.1132, MAE: 3.0370, R²: 0.7950
# Fold 3 - MSE: 21.9015, RMSE: 4.6799, MAE: 3.5602, R²: 0.7410
# Fold 4 - MSE: 20.5636, RMSE: 4.5347, MAE: 3.4867, R²: 0.7531
# Fold 5 - MSE: 17.9405, RMSE: 4.2356, MAE: 3.1753, R²: 0.7884
# Fold 6 - MSE: 23.4385, RMSE: 4.8413, MAE: 3.7274, R²: 0.7219
# Fold 7 - MSE: 21.0601, RMSE: 4.5891, MAE: 3.5356, R²: 0.7443
# Fold 8 - MSE: 13.7979, RMSE: 3.7146, MAE: 2.6842, R²: 0.8331
# Fold 9 - MSE: 17.4007, RMSE: 4.1714, MAE: 3.1536, R²: 0.7908
# Fold 10 - MSE: 16.8741, RMSE: 4.1078, MAE: 3.0570, R²: 0.7966
# Average - MSE: 18.9487, RMSE: 4.3414, MAE: 3.2773, R²: 0.7730

# %%
import torch
from torch_geometric.utils import k_hop_subgraph
from sklearn.model_selection import KFold
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch.nn.functional as F
from torch_geometric.nn import GATv2Conv
import itertools
import random

# 定义GATv2模型
class GATv2(torch.nn.Module):
    def __init__(self, in_channels, hidden1, hidden2, out_channels, dropout):
        super(GATv2, self).__init__()
        self.conv1 = GATv2Conv(in_channels, hidden1, heads=1)
        self.bn1 = torch.nn.BatchNorm1d(hidden1)  # Batch normalization
        self.conv2 = GATv2Conv(hidden1, hidden2, heads=1)
        self.bn2 = torch.nn.BatchNorm1d(hidden2)  # Batch normalization
        self.fc1 = torch.nn.Linear(hidden2, out_channels)
        self.dropout = dropout

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = self.bn1(x)  # Batch normalization
        x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)  # Dropout
        x = self.conv2(x, edge_index)
        x = self.bn2(x)  # Batch normalization
        x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)  # Dropout
        x = self.fc1(x)
        return x

def train(model, optimizer, data):
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index)
    loss = F.mse_loss(out, data.y)
    loss.backward()
    optimizer.step()
    return loss.item()

def evaluate(model, data):
    model.eval()
    with torch.no_grad():
        out = model(data.x, data.edge_index)
        loss = F.mse_loss(out, data.y).item()
    return loss

# 定义早停机制
class EarlyStopping:
    def __init__(self, patience=10, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = float('inf')
        self.counter = 0

    def step(self, loss):
        if loss < self.best_loss - self.min_delta:
            self.best_loss = loss
            self.counter = 0
        else:
            self.counter += 1

        return self.counter >= self.patience

# 定义划分子图的函数
def create_subgraph(data, train_idx, test_idx, num_hops):
    train_idx = torch.tensor(train_idx, dtype=torch.long, device=data.edge_index.device)
    test_idx = torch.tensor(test_idx, dtype=torch.long, device=data.edge_index.device)
    
    # 获取训练集子图，包含 train_idx 节点以及 num_hops 范围内的邻居
    train_subgraph = k_hop_subgraph(train_idx, num_hops, data.edge_index, relabel_nodes=True)
    train_edge_index, train_x, train_y = train_subgraph[1], data.x[train_subgraph[0]], data.y[train_subgraph[0]]
    
    # 获取测试集子图，包含 test_idx 节点以及 num_hops 范围内的邻居
    test_subgraph = k_hop_subgraph(test_idx, num_hops, data.edge_index, relabel_nodes=True)
    test_edge_index, test_x, test_y = test_subgraph[1], data.x[test_subgraph[0]], data.y[test_subgraph[0]]
    
    return (train_x, train_edge_index, train_y), (test_x, test_edge_index, test_y)

# 超参数搜索函数
def hyperparameter_search(data, param_space, k=5, num_hops=1, num_samples=20):
    best_loss = float('inf')
    best_params = None
    random_params = [dict(zip(param_space, v)) for v in random.sample(list(itertools.product(*param_space.values())), num_samples)]
    
    for param_idx, params in enumerate(random_params):
        print(f'Starting hyperparameter set {param_idx + 1}/{num_samples}: {params}')
        kf = KFold(n_splits=k, shuffle=True, random_state=42)
        fold_losses = []
        
        for fold, (train_idx, test_idx) in enumerate(kf.split(np.arange(data.num_nodes))):
            print(f'Starting fold {fold + 1}/{k} for hyperparameter set {param_idx + 1}/{num_samples}')
            (train_x, train_edge_index, train_y), (test_x, test_edge_index, test_y) = create_subgraph(data, train_idx, test_idx, num_hops)
            
            # 重新初始化模型和优化器
            model = GATv2(
                in_channels=train_x.shape[1], 
                hidden1=params['hidden1'], 
                hidden2=params['hidden2'], 
                out_channels=train_y.shape[1], 
                dropout=params['dropout']
            )
            optimizer = torch.optim.Adam(model.parameters(), lr=params['lr'], weight_decay=params['weight_decay'])
            scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)
            early_stopping = EarlyStopping(patience=10)
            
            # 训练模型
            for epoch in range(params['num_epochs']):
                loss = train(model, optimizer, data)
                val_loss = evaluate(model, data)
                scheduler.step(val_loss)
                
                if (epoch + 1) % 10 == 0:
                    print(f'Hyperparameter set {param_idx + 1}/{num_samples}, Fold {fold + 1}/{k}, Epoch {epoch + 1}/{params["num_epochs"]}, Loss: {loss:.4f}, Val Loss: {val_loss:.4f}')
                
                if early_stopping.step(val_loss):
                    print(f'Early stopping at epoch {epoch + 1}')
                    break
            
            # 测试模型
            model.eval()
            with torch.no_grad():
                pred = model(test_x, test_edge_index)
                fold_loss = F.mse_loss(pred, test_y).item()
                fold_losses.append(fold_loss)
        
        avg_fold_loss = np.mean(fold_losses)
        print(f'Average loss for hyperparameter set {param_idx + 1}/{num_samples}: {avg_fold_loss:.4f}')
        if avg_fold_loss < best_loss:
            best_loss = avg_fold_loss
            best_params = params
    
    return best_params, best_loss

# 定义K-Fold交叉验证
def k_fold_cross_validation(data, best_params, k=5, num_hops=1):
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    results = []

    all_indices = np.arange(data.num_nodes)
    
    for fold, (train_idx, test_idx) in enumerate(kf.split(all_indices)):
        print(f'Starting fold {fold + 1}/{k}')
        (train_x, train_edge_index, train_y), (test_x, test_edge_index, test_y) = create_subgraph(data, train_idx, test_idx, num_hops)
        
        # 重新初始化模型和优化器
        model = GATv2(
            in_channels=train_x.shape[1], 
            hidden1=best_params['hidden1'], 
            hidden2=best_params['hidden2'], 
            out_channels=train_y.shape[1], 
            dropout=best_params['dropout']
        )
        optimizer = torch.optim.Adam(model.parameters(), lr=best_params['lr'], weight_decay=best_params['weight_decay'])
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)
        early_stopping = EarlyStopping(patience=10)
        
        # 训练模型
        model.train()
        for epoch in range(best_params['num_epochs']):
            loss = train(model, optimizer, data)
            val_loss = evaluate(model, data)
            scheduler.step(val_loss)
            
            if (epoch + 1) % 10 == 0:
                print(f'Fold {fold + 1}/{k}, Epoch {epoch + 1}/{best_params["num_epochs"]}, Loss: {loss:.4f}, Val Loss: {val_loss:.4f}')
            
            if early_stopping.step(val_loss):
                print(f'Early stopping at epoch {epoch + 1}')
                break
        
        # 测试模型
        model.eval()
        with torch.no_grad():
            pred = model(test_x, test_edge_index)
            y_true = test_y.numpy()
            y_pred = pred.numpy()
            
            mse = mean_squared_error(y_true, y_pred)
            rmse = np.sqrt(mse)
            mae = mean_absolute_error(y_true, y_pred)
            r2 = r2_score(y_true, y_pred)
        
        print(f'Fold {fold + 1} results - MSE: {mse:.4f}, RMSE: {rmse:.4f}, MAE: {mae:.4f}, R²: {r2:.4f}')
        results.append((mse, rmse, mae, r2))
    
    return results

# 假设你已经有一个数据对象 data
# data = ...

# 定义超参数空间
param_space = {
    'lr': [0.001, 0.005, 0.01],
    'weight_decay': [5e-4, 1e-3, 5e-3],
    'hidden1': [32, 64, 128],
    'hidden2': [16, 32, 64],
    'dropout': [0.3, 0.5, 0.7],
    'num_epochs': [200]
}

# 使用K-Fold交叉验证进行超参数搜索
best_params, best_loss = hyperparameter_search(data, param_space)
print(f'Best params: {best_params}, Best loss: {best_loss:.4f}')

# 使用最佳超参数进行K-Fold交叉验证
results = k_fold_cross_validation(data, best_params)

# 打印K-Fold结果
for fold, (mse, rmse, mae, r2) in enumerate(results):
    print(f'Fold {fold + 1} - MSE: {mse:.4f}, RMSE: {rmse:.4f}, MAE: {mae:.4f}, R²: {r2:.4f}')

# 计算平均结果
avg_results = np.mean(results, axis=0)
print(f'Average - MSE: {avg_results[0]:.4f}, RMSE: {avg_results[1]:.4f}, MAE: {avg_results[2]:.4f}, R²: {avg_results[3]:.4f}')
# Out:
# Starting hyperparameter set 1/20: {'lr': 0.005, 'weight_decay': 0.005, 'hidden1': 32, 'hidden2': 64, 'dropout': 0.7, 'num_epochs': 200}
# Starting fold 1/5 for hyperparameter set 1/20
# Hyperparameter set 1/20, Fold 1/5, Epoch 10/200, Loss: 254.7401, Val Loss: 242.0734
# Hyperparameter set 1/20, Fold 1/5, Epoch 20/200, Loss: 198.6641, Val Loss: 165.9631
# Hyperparameter set 1/20, Fold 1/5, Epoch 30/200, Loss: 145.0933, Val Loss: 117.1710
# Hyperparameter set 1/20, Fold 1/5, Epoch 40/200, Loss: 103.9970, Val Loss: 86.0367
# Hyperparameter set 1/20, Fold 1/5, Epoch 50/200, Loss: 77.2997, Val Loss: 64.1659
# Hyperparameter set 1/20, Fold 1/5, Epoch 60/200, Loss: 60.4422, Val Loss: 50.3068
# Hyperparameter set 1/20, Fold 1/5, Epoch 70/200, Loss: 52.0132, Val Loss: 42.3075
# Hyperparameter set 1/20, Fold 1/5, Epoch 80/200, Loss: 48.0542, Val Loss: 38.2732
# Hyperparameter set 1/20, Fold 1/5, Epoch 90/200, Loss: 47.1615, Val Loss: 34.7121
# Hyperparameter set 1/20, Fold 1/5, Epoch 100/200, Loss: 47.4443, Val Loss: 32.5841
# Hyperparameter set 1/20, Fold 1/5, Epoch 110/200, Loss: 42.9741, Val Loss: 31.1250
# Hyperparameter set 1/20, Fold 1/5, Epoch 120/200, Loss: 43.2645, Val Loss: 29.8313
# Hyperparameter set 1/20, Fold 1/5, Epoch 130/200, Loss: 41.6572, Val Loss: 28.7714
# Hyperparameter set 1/20, Fold 1/5, Epoch 140/200, Loss: 40.9460, Val Loss: 28.2522
# Hyperparameter set 1/20, Fold 1/5, Epoch 150/200, Loss: 39.2878, Val Loss: 27.2046
# Hyperparameter set 1/20, Fold 1/5, Epoch 160/200, Loss: 39.1596, Val Loss: 25.5557
# Hyperparameter set 1/20, Fold 1/5, Epoch 170/200, Loss: 38.8677, Val Loss: 24.7463
# Hyperparameter set 1/20, Fold 1/5, Epoch 180/200, Loss: 37.8151, Val Loss: 23.6099
# Hyperparameter set 1/20, Fold 1/5, Epoch 190/200, Loss: 35.8670, Val Loss: 23.6085
# Early stopping at epoch 192
# Starting fold 2/5 for hyperparameter set 1/20
# Hyperparameter set 1/20, Fold 2/5, Epoch 10/200, Loss: 250.9192, Val Loss: 262.5757
# Hyperparameter set 1/20, Fold 2/5, Epoch 20/200, Loss: 188.4886, Val Loss: 181.2437
# Hyperparameter set 1/20, Fold 2/5, Epoch 30/200, Loss: 135.8670, Val Loss: 127.2798
# Hyperparameter set 1/20, Fold 2/5, Epoch 40/200, Loss: 97.1263, Val Loss: 88.3693
# Hyperparameter set 1/20, Fold 2/5, Epoch 50/200, Loss: 71.8972, Val Loss: 59.4593
# Hyperparameter set 1/20, Fold 2/5, Epoch 60/200, Loss: 58.0482, Val Loss: 43.6208
# Hyperparameter set 1/20, Fold 2/5, Epoch 70/200, Loss: 53.0420, Val Loss: 35.4220
# Hyperparameter set 1/20, Fold 2/5, Epoch 80/200, Loss: 47.1186, Val Loss: 31.4486
# Hyperparameter set 1/20, Fold 2/5, Epoch 90/200, Loss: 45.2056, Val Loss: 30.0476
# Hyperparameter set 1/20, Fold 2/5, Epoch 100/200, Loss: 44.0342, Val Loss: 29.3072
# Hyperparameter set 1/20, Fold 2/5, Epoch 110/200, Loss: 42.7870, Val Loss: 28.2724
# Hyperparameter set 1/20, Fold 2/5, Epoch 120/200, Loss: 43.1125, Val Loss: 27.5152
# Hyperparameter set 1/20, Fold 2/5, Epoch 130/200, Loss: 43.1954, Val Loss: 27.3775
# Hyperparameter set 1/20, Fold 2/5, Epoch 140/200, Loss: 42.2394, Val Loss: 27.3583
# Hyperparameter set 1/20, Fold 2/5, Epoch 150/200, Loss: 40.6735, Val Loss: 27.3478
# Early stopping at epoch 155
# Starting fold 3/5 for hyperparameter set 1/20
# Hyperparameter set 1/20, Fold 3/5, Epoch 10/200, Loss: 250.0435, Val Loss: 258.2232
# Hyperparameter set 1/20, Fold 3/5, Epoch 20/200, Loss: 189.6537, Val Loss: 182.9092
# Hyperparameter set 1/20, Fold 3/5, Epoch 30/200, Loss: 135.8745, Val Loss: 123.5256
# Hyperparameter set 1/20, Fold 3/5, Epoch 40/200, Loss: 94.5351, Val Loss: 85.3205
# Hyperparameter set 1/20, Fold 3/5, Epoch 50/200, Loss: 71.0626, Val Loss: 59.1378
# Hyperparameter set 1/20, Fold 3/5, Epoch 60/200, Loss: 56.0317, Val Loss: 43.4110
# Hyperparameter set 1/20, Fold 3/5, Epoch 70/200, Loss: 49.3859, Val Loss: 36.0874
# Hyperparameter set 1/20, Fold 3/5, Epoch 80/200, Loss: 47.2860, Val Loss: 34.1311
# Hyperparameter set 1/20, Fold 3/5, Epoch 90/200, Loss: 43.6041, Val Loss: 30.6982
# Hyperparameter set 1/20, Fold 3/5, Epoch 100/200, Loss: 43.3831, Val Loss: 28.4167
# Hyperparameter set 1/20, Fold 3/5, Epoch 110/200, Loss: 41.9849, Val Loss: 27.6603
# Hyperparameter set 1/20, Fold 3/5, Epoch 120/200, Loss: 41.7677, Val Loss: 26.1556
# Hyperparameter set 1/20, Fold 3/5, Epoch 130/200, Loss: 40.1501, Val Loss: 25.1108
# Hyperparameter set 1/20, Fold 3/5, Epoch 140/200, Loss: 39.5357, Val Loss: 24.9565
# Hyperparameter set 1/20, Fold 3/5, Epoch 150/200, Loss: 38.9513, Val Loss: 24.4853
# Hyperparameter set 1/20, Fold 3/5, Epoch 160/200, Loss: 39.1137, Val Loss: 24.3300
# Early stopping at epoch 168
# Starting fold 4/5 for hyperparameter set 1/20
# Hyperparameter set 1/20, Fold 4/5, Epoch 10/200, Loss: 251.7830, Val Loss: 249.4614
# Hyperparameter set 1/20, Fold 4/5, Epoch 20/200, Loss: 192.8840, Val Loss: 182.0067
# Hyperparameter set 1/20, Fold 4/5, Epoch 30/200, Loss: 139.3793, Val Loss: 121.7418
# Hyperparameter set 1/20, Fold 4/5, Epoch 40/200, Loss: 100.6051, Val Loss: 82.6758
# Hyperparameter set 1/20, Fold 4/5, Epoch 50/200, Loss: 75.1763, Val Loss: 61.2977
# Hyperparameter set 1/20, Fold 4/5, Epoch 60/200, Loss: 61.0925, Val Loss: 47.2816
# Hyperparameter set 1/20, Fold 4/5, Epoch 70/200, Loss: 53.0662, Val Loss: 39.2124
# Hyperparameter set 1/20, Fold 4/5, Epoch 80/200, Loss: 49.2569, Val Loss: 35.2641
# Hyperparameter set 1/20, Fold 4/5, Epoch 90/200, Loss: 45.5323, Val Loss: 33.0693
# Hyperparameter set 1/20, Fold 4/5, Epoch 100/200, Loss: 44.7546, Val Loss: 31.2105
# Hyperparameter set 1/20, Fold 4/5, Epoch 110/200, Loss: 43.3021, Val Loss: 29.4489
# Hyperparameter set 1/20, Fold 4/5, Epoch 120/200, Loss: 42.7074, Val Loss: 27.9470
# Hyperparameter set 1/20, Fold 4/5, Epoch 130/200, Loss: 40.8606, Val Loss: 27.4269
# Hyperparameter set 1/20, Fold 4/5, Epoch 140/200, Loss: 39.8489, Val Loss: 26.2678
# Hyperparameter set 1/20, Fold 4/5, Epoch 150/200, Loss: 39.6644, Val Loss: 25.8424
# Hyperparameter set 1/20, Fold 4/5, Epoch 160/200, Loss: 39.2389, Val Loss: 25.4129
# Hyperparameter set 1/20, Fold 4/5, Epoch 170/200, Loss: 38.3337, Val Loss: 24.2273
# Hyperparameter set 1/20, Fold 4/5, Epoch 180/200, Loss: 37.4412, Val Loss: 23.5222
# Hyperparameter set 1/20, Fold 4/5, Epoch 190/200, Loss: 37.9650, Val Loss: 23.4525
# Early stopping at epoch 192
# Starting fold 5/5 for hyperparameter set 1/20
# Hyperparameter set 1/20, Fold 5/5, Epoch 10/200, Loss: 264.4043, Val Loss: 259.9328
# Hyperparameter set 1/20, Fold 5/5, Epoch 20/200, Loss: 207.2583, Val Loss: 191.3791
# Hyperparameter set 1/20, Fold 5/5, Epoch 30/200, Loss: 151.8156, Val Loss: 135.1639
# Hyperparameter set 1/20, Fold 5/5, Epoch 40/200, Loss: 111.0345, Val Loss: 92.0638
# Hyperparameter set 1/20, Fold 5/5, Epoch 50/200, Loss: 81.4771, Val Loss: 67.1632
# Hyperparameter set 1/20, Fold 5/5, Epoch 60/200, Loss: 62.8600, Val Loss: 50.1888
# Hyperparameter set 1/20, Fold 5/5, Epoch 70/200, Loss: 53.6234, Val Loss: 41.1408
# Hyperparameter set 1/20, Fold 5/5, Epoch 80/200, Loss: 48.8336, Val Loss: 35.7976
# Hyperparameter set 1/20, Fold 5/5, Epoch 90/200, Loss: 48.8844, Val Loss: 33.1988
# Hyperparameter set 1/20, Fold 5/5, Epoch 100/200, Loss: 44.4990, Val Loss: 30.5808
# Hyperparameter set 1/20, Fold 5/5, Epoch 110/200, Loss: 45.9854, Val Loss: 30.4113
# Hyperparameter set 1/20, Fold 5/5, Epoch 120/200, Loss: 44.4618, Val Loss: 29.4387
# Hyperparameter set 1/20, Fold 5/5, Epoch 130/200, Loss: 44.4994, Val Loss: 29.2235
# Hyperparameter set 1/20, Fold 5/5, Epoch 140/200, Loss: 44.6968, Val Loss: 29.1151
# Hyperparameter set 1/20, Fold 5/5, Epoch 150/200, Loss: 43.4140, Val Loss: 28.8362
# Hyperparameter set 1/20, Fold 5/5, Epoch 160/200, Loss: 45.3028, Val Loss: 28.7514
# Early stopping at epoch 169
# Average loss for hyperparameter set 1/20: 26.5465
# Starting hyperparameter set 2/20: {'lr': 0.01, 'weight_decay': 0.001, 'hidden1': 64, 'hidden2': 16, 'dropout': 0.5, 'num_epochs': 200}
# Starting fold 1/5 for hyperparameter set 2/20
# Hyperparameter set 2/20, Fold 1/5, Epoch 10/200, Loss: 271.4014, Val Loss: 237.6351
# Hyperparameter set 2/20, Fold 1/5, Epoch 20/200, Loss: 229.4102, Val Loss: 199.2826
# Hyperparameter set 2/20, Fold 1/5, Epoch 30/200, Loss: 183.5712, Val Loss: 164.5709
# Hyperparameter set 2/20, Fold 1/5, Epoch 40/200, Loss: 137.8779, Val Loss: 118.3765
# Hyperparameter set 2/20, Fold 1/5, Epoch 50/200, Loss: 98.5676, Val Loss: 81.9647
# Hyperparameter set 2/20, Fold 1/5, Epoch 60/200, Loss: 72.1465, Val Loss: 56.1021
# Hyperparameter set 2/20, Fold 1/5, Epoch 70/200, Loss: 56.7804, Val Loss: 43.8756
# Hyperparameter set 2/20, Fold 1/5, Epoch 80/200, Loss: 49.5342, Val Loss: 37.8742
# Hyperparameter set 2/20, Fold 1/5, Epoch 90/200, Loss: 47.5866, Val Loss: 28.0272
# Hyperparameter set 2/20, Fold 1/5, Epoch 100/200, Loss: 45.5112, Val Loss: 24.9761
# Hyperparameter set 2/20, Fold 1/5, Epoch 110/200, Loss: 45.0218, Val Loss: 24.4852
# Hyperparameter set 2/20, Fold 1/5, Epoch 120/200, Loss: 41.7224, Val Loss: 23.7629
# Hyperparameter set 2/20, Fold 1/5, Epoch 130/200, Loss: 39.9732, Val Loss: 20.4540
# Hyperparameter set 2/20, Fold 1/5, Epoch 140/200, Loss: 38.4520, Val Loss: 18.9862
# Hyperparameter set 2/20, Fold 1/5, Epoch 150/200, Loss: 37.1395, Val Loss: 18.3804
# Hyperparameter set 2/20, Fold 1/5, Epoch 160/200, Loss: 37.0988, Val Loss: 16.4832
# Hyperparameter set 2/20, Fold 1/5, Epoch 170/200, Loss: 34.7512, Val Loss: 16.2783
# Hyperparameter set 2/20, Fold 1/5, Epoch 180/200, Loss: 34.5910, Val Loss: 15.9431
# Hyperparameter set 2/20, Fold 1/5, Epoch 190/200, Loss: 33.1879, Val Loss: 15.7236
# Hyperparameter set 2/20, Fold 1/5, Epoch 200/200, Loss: 35.0015, Val Loss: 15.7911
# Starting fold 2/5 for hyperparameter set 2/20
# Hyperparameter set 2/20, Fold 2/5, Epoch 10/200, Loss: 273.2047, Val Loss: 243.4756
# Hyperparameter set 2/20, Fold 2/5, Epoch 20/200, Loss: 233.0705, Val Loss: 204.7883
# Hyperparameter set 2/20, Fold 2/5, Epoch 30/200, Loss: 191.1501, Val Loss: 157.7448
# Hyperparameter set 2/20, Fold 2/5, Epoch 40/200, Loss: 146.1523, Val Loss: 115.7910
# Hyperparameter set 2/20, Fold 2/5, Epoch 50/200, Loss: 107.1816, Val Loss: 86.0777
# Hyperparameter set 2/20, Fold 2/5, Epoch 60/200, Loss: 79.0026, Val Loss: 63.7958
# Hyperparameter set 2/20, Fold 2/5, Epoch 70/200, Loss: 60.1173, Val Loss: 47.2988
# Hyperparameter set 2/20, Fold 2/5, Epoch 80/200, Loss: 53.5894, Val Loss: 34.7636
# Hyperparameter set 2/20, Fold 2/5, Epoch 90/200, Loss: 48.4555, Val Loss: 29.5621
# Hyperparameter set 2/20, Fold 2/5, Epoch 100/200, Loss: 45.5184, Val Loss: 27.2561
# Hyperparameter set 2/20, Fold 2/5, Epoch 110/200, Loss: 44.8930, Val Loss: 25.7019
# Hyperparameter set 2/20, Fold 2/5, Epoch 120/200, Loss: 42.9313, Val Loss: 23.0231
# Hyperparameter set 2/20, Fold 2/5, Epoch 130/200, Loss: 43.5921, Val Loss: 22.6353
# Hyperparameter set 2/20, Fold 2/5, Epoch 140/200, Loss: 41.4493, Val Loss: 22.6035
# Hyperparameter set 2/20, Fold 2/5, Epoch 150/200, Loss: 42.2550, Val Loss: 21.7062
# Hyperparameter set 2/20, Fold 2/5, Epoch 160/200, Loss: 42.3951, Val Loss: 21.7785
# Early stopping at epoch 165
# Starting fold 3/5 for hyperparameter set 2/20
# Hyperparameter set 2/20, Fold 3/5, Epoch 10/200, Loss: 286.2301, Val Loss: 259.0560
# Hyperparameter set 2/20, Fold 3/5, Epoch 20/200, Loss: 249.4712, Val Loss: 214.9556
# Hyperparameter set 2/20, Fold 3/5, Epoch 30/200, Loss: 204.9442, Val Loss: 175.0094
# Hyperparameter set 2/20, Fold 3/5, Epoch 40/200, Loss: 157.7185, Val Loss: 125.7696
# Hyperparameter set 2/20, Fold 3/5, Epoch 50/200, Loss: 112.4174, Val Loss: 86.9581
# Hyperparameter set 2/20, Fold 3/5, Epoch 60/200, Loss: 80.1450, Val Loss: 64.4053
# Hyperparameter set 2/20, Fold 3/5, Epoch 70/200, Loss: 60.2513, Val Loss: 42.4637
# Hyperparameter set 2/20, Fold 3/5, Epoch 80/200, Loss: 53.8002, Val Loss: 34.7319
# Hyperparameter set 2/20, Fold 3/5, Epoch 90/200, Loss: 50.8226, Val Loss: 30.0691
# Hyperparameter set 2/20, Fold 3/5, Epoch 100/200, Loss: 47.6746, Val Loss: 26.7758
# Hyperparameter set 2/20, Fold 3/5, Epoch 110/200, Loss: 46.3193, Val Loss: 24.4202
# Hyperparameter set 2/20, Fold 3/5, Epoch 120/200, Loss: 45.7434, Val Loss: 24.1235
# Hyperparameter set 2/20, Fold 3/5, Epoch 130/200, Loss: 47.0597, Val Loss: 23.8897
# Hyperparameter set 2/20, Fold 3/5, Epoch 140/200, Loss: 45.5559, Val Loss: 23.4558
# Hyperparameter set 2/20, Fold 3/5, Epoch 150/200, Loss: 45.0580, Val Loss: 23.2060
# Hyperparameter set 2/20, Fold 3/5, Epoch 160/200, Loss: 45.3322, Val Loss: 22.9050
# Hyperparameter set 2/20, Fold 3/5, Epoch 170/200, Loss: 43.7685, Val Loss: 22.8594
# Hyperparameter set 2/20, Fold 3/5, Epoch 180/200, Loss: 45.5067, Val Loss: 22.7335
# Hyperparameter set 2/20, Fold 3/5, Epoch 190/200, Loss: 43.8655, Val Loss: 22.6801
# Hyperparameter set 2/20, Fold 3/5, Epoch 200/200, Loss: 43.9605, Val Loss: 22.6114
# Starting fold 4/5 for hyperparameter set 2/20
# Hyperparameter set 2/20, Fold 4/5, Epoch 10/200, Loss: 276.2760, Val Loss: 253.1960
# Hyperparameter set 2/20, Fold 4/5, Epoch 20/200, Loss: 237.1652, Val Loss: 198.7360
# Hyperparameter set 2/20, Fold 4/5, Epoch 30/200, Loss: 197.1244, Val Loss: 174.5102
# Hyperparameter set 2/20, Fold 4/5, Epoch 40/200, Loss: 152.2141, Val Loss: 122.7461
# Hyperparameter set 2/20, Fold 4/5, Epoch 50/200, Loss: 110.5076, Val Loss: 90.1787
# Hyperparameter set 2/20, Fold 4/5, Epoch 60/200, Loss: 78.8325, Val Loss: 60.0503
# Hyperparameter set 2/20, Fold 4/5, Epoch 70/200, Loss: 59.3923, Val Loss: 41.2412
# Hyperparameter set 2/20, Fold 4/5, Epoch 80/200, Loss: 52.9081, Val Loss: 35.1536
# Hyperparameter set 2/20, Fold 4/5, Epoch 90/200, Loss: 51.3169, Val Loss: 32.0945
# Hyperparameter set 2/20, Fold 4/5, Epoch 100/200, Loss: 46.0568, Val Loss: 27.9866
# Hyperparameter set 2/20, Fold 4/5, Epoch 110/200, Loss: 45.5207, Val Loss: 24.5628
# Hyperparameter set 2/20, Fold 4/5, Epoch 120/200, Loss: 44.8239, Val Loss: 23.3015
# Hyperparameter set 2/20, Fold 4/5, Epoch 130/200, Loss: 43.5990, Val Loss: 22.5265
# Hyperparameter set 2/20, Fold 4/5, Epoch 140/200, Loss: 43.2612, Val Loss: 22.3772
# Hyperparameter set 2/20, Fold 4/5, Epoch 150/200, Loss: 43.4484, Val Loss: 21.8419
# Hyperparameter set 2/20, Fold 4/5, Epoch 160/200, Loss: 44.3609, Val Loss: 21.6313
# Hyperparameter set 2/20, Fold 4/5, Epoch 170/200, Loss: 42.2779, Val Loss: 21.7689
# Early stopping at epoch 174
# Starting fold 5/5 for hyperparameter set 2/20
# Hyperparameter set 2/20, Fold 5/5, Epoch 10/200, Loss: 264.1057, Val Loss: 233.5133
# Hyperparameter set 2/20, Fold 5/5, Epoch 20/200, Loss: 218.3396, Val Loss: 175.7770
# Hyperparameter set 2/20, Fold 5/5, Epoch 30/200, Loss: 168.3152, Val Loss: 138.3141
# Hyperparameter set 2/20, Fold 5/5, Epoch 40/200, Loss: 121.5607, Val Loss: 93.4659
# Hyperparameter set 2/20, Fold 5/5, Epoch 50/200, Loss: 84.2334, Val Loss: 66.6544
# Hyperparameter set 2/20, Fold 5/5, Epoch 60/200, Loss: 62.8955, Val Loss: 45.6789
# Hyperparameter set 2/20, Fold 5/5, Epoch 70/200, Loss: 52.2008, Val Loss: 33.8229
# Hyperparameter set 2/20, Fold 5/5, Epoch 80/200, Loss: 49.7755, Val Loss: 31.8281
# Hyperparameter set 2/20, Fold 5/5, Epoch 90/200, Loss: 45.3553, Val Loss: 26.5747
# Hyperparameter set 2/20, Fold 5/5, Epoch 100/200, Loss: 43.5909, Val Loss: 24.7726
# Hyperparameter set 2/20, Fold 5/5, Epoch 110/200, Loss: 43.0920, Val Loss: 23.9143
# Hyperparameter set 2/20, Fold 5/5, Epoch 120/200, Loss: 40.3836, Val Loss: 21.9498
# Hyperparameter set 2/20, Fold 5/5, Epoch 130/200, Loss: 40.9793, Val Loss: 21.1007
# Hyperparameter set 2/20, Fold 5/5, Epoch 140/200, Loss: 40.6872, Val Loss: 20.5291
# Hyperparameter set 2/20, Fold 5/5, Epoch 150/200, Loss: 41.1340, Val Loss: 20.3680
# Hyperparameter set 2/20, Fold 5/5, Epoch 160/200, Loss: 41.1847, Val Loss: 20.0924
# Hyperparameter set 2/20, Fold 5/5, Epoch 170/200, Loss: 40.1594, Val Loss: 19.9091
# Hyperparameter set 2/20, Fold 5/5, Epoch 180/200, Loss: 41.6472, Val Loss: 19.8034
# Hyperparameter set 2/20, Fold 5/5, Epoch 190/200, Loss: 39.0381, Val Loss: 19.8353
# Early stopping at epoch 196
# Average loss for hyperparameter set 2/20: 22.0478
# Starting hyperparameter set 3/20: {'lr': 0.005, 'weight_decay': 0.005, 'hidden1': 32, 'hidden2': 16, 'dropout': 0.3, 'num_epochs': 200}
# Starting fold 1/5 for hyperparameter set 3/20
# Hyperparameter set 3/20, Fold 1/5, Epoch 10/200, Loss: 279.1238, Val Loss: 264.6508
# Hyperparameter set 3/20, Fold 1/5, Epoch 20/200, Loss: 259.0980, Val Loss: 241.0306
# Hyperparameter set 3/20, Fold 1/5, Epoch 30/200, Loss: 236.7203, Val Loss: 225.4045
# Hyperparameter set 3/20, Fold 1/5, Epoch 40/200, Loss: 211.5126, Val Loss: 203.8184
# Hyperparameter set 3/20, Fold 1/5, Epoch 50/200, Loss: 186.9013, Val Loss: 173.8447
# Hyperparameter set 3/20, Fold 1/5, Epoch 60/200, Loss: 160.6225, Val Loss: 146.0233
# Hyperparameter set 3/20, Fold 1/5, Epoch 70/200, Loss: 134.9042, Val Loss: 126.2414
# Hyperparameter set 3/20, Fold 1/5, Epoch 80/200, Loss: 112.1696, Val Loss: 103.7289
# Hyperparameter set 3/20, Fold 1/5, Epoch 90/200, Loss: 91.3095, Val Loss: 87.8386
# Hyperparameter set 3/20, Fold 1/5, Epoch 100/200, Loss: 74.0204, Val Loss: 70.8542
# Hyperparameter set 3/20, Fold 1/5, Epoch 110/200, Loss: 60.5698, Val Loss: 58.3975
# Hyperparameter set 3/20, Fold 1/5, Epoch 120/200, Loss: 49.7040, Val Loss: 46.3891
# Hyperparameter set 3/20, Fold 1/5, Epoch 130/200, Loss: 44.3299, Val Loss: 39.1504
# Hyperparameter set 3/20, Fold 1/5, Epoch 140/200, Loss: 38.6425, Val Loss: 34.6757
# Hyperparameter set 3/20, Fold 1/5, Epoch 150/200, Loss: 34.9956, Val Loss: 29.4262
# Hyperparameter set 3/20, Fold 1/5, Epoch 160/200, Loss: 33.5818, Val Loss: 26.5928
# Hyperparameter set 3/20, Fold 1/5, Epoch 170/200, Loss: 31.5703, Val Loss: 23.9967
# Hyperparameter set 3/20, Fold 1/5, Epoch 180/200, Loss: 30.1597, Val Loss: 22.4475
# Hyperparameter set 3/20, Fold 1/5, Epoch 190/200, Loss: 30.0905, Val Loss: 20.9184
# Hyperparameter set 3/20, Fold 1/5, Epoch 200/200, Loss: 28.6621, Val Loss: 20.3516
# Starting fold 2/5 for hyperparameter set 3/20
# Hyperparameter set 3/20, Fold 2/5, Epoch 10/200, Loss: 295.0891, Val Loss: 282.0678
# Hyperparameter set 3/20, Fold 2/5, Epoch 20/200, Loss: 277.0771, Val Loss: 255.1765
# Hyperparameter set 3/20, Fold 2/5, Epoch 30/200, Loss: 257.7035, Val Loss: 241.4254
# Hyperparameter set 3/20, Fold 2/5, Epoch 40/200, Loss: 236.4486, Val Loss: 219.1924
# Hyperparameter set 3/20, Fold 2/5, Epoch 50/200, Loss: 211.8341, Val Loss: 192.2971
# Hyperparameter set 3/20, Fold 2/5, Epoch 60/200, Loss: 186.7301, Val Loss: 174.1678
# Hyperparameter set 3/20, Fold 2/5, Epoch 70/200, Loss: 162.6362, Val Loss: 153.7494
# Hyperparameter set 3/20, Fold 2/5, Epoch 80/200, Loss: 136.9689, Val Loss: 135.6479
# Hyperparameter set 3/20, Fold 2/5, Epoch 90/200, Loss: 113.0636, Val Loss: 114.2239
# Hyperparameter set 3/20, Fold 2/5, Epoch 100/200, Loss: 93.3962, Val Loss: 93.0053
# Hyperparameter set 3/20, Fold 2/5, Epoch 110/200, Loss: 73.9437, Val Loss: 73.2731
# Hyperparameter set 3/20, Fold 2/5, Epoch 120/200, Loss: 59.4953, Val Loss: 57.8052
# Hyperparameter set 3/20, Fold 2/5, Epoch 130/200, Loss: 49.8152, Val Loss: 46.7161
# Hyperparameter set 3/20, Fold 2/5, Epoch 140/200, Loss: 41.2329, Val Loss: 35.3585
# Hyperparameter set 3/20, Fold 2/5, Epoch 150/200, Loss: 37.7816, Val Loss: 30.6709
# Hyperparameter set 3/20, Fold 2/5, Epoch 160/200, Loss: 35.8198, Val Loss: 27.6261
# Hyperparameter set 3/20, Fold 2/5, Epoch 170/200, Loss: 33.8336, Val Loss: 24.9757
# Hyperparameter set 3/20, Fold 2/5, Epoch 180/200, Loss: 32.9172, Val Loss: 21.7939
# Hyperparameter set 3/20, Fold 2/5, Epoch 190/200, Loss: 32.6865, Val Loss: 20.3254
# Hyperparameter set 3/20, Fold 2/5, Epoch 200/200, Loss: 31.4982, Val Loss: 20.8379
# Starting fold 3/5 for hyperparameter set 3/20
# Hyperparameter set 3/20, Fold 3/5, Epoch 10/200, Loss: 287.4116, Val Loss: 286.5020
# Hyperparameter set 3/20, Fold 3/5, Epoch 20/200, Loss: 266.9334, Val Loss: 253.2061
# Hyperparameter set 3/20, Fold 3/5, Epoch 30/200, Loss: 245.7881, Val Loss: 232.2676
# Hyperparameter set 3/20, Fold 3/5, Epoch 40/200, Loss: 224.5894, Val Loss: 214.7908
# Hyperparameter set 3/20, Fold 3/5, Epoch 50/200, Loss: 200.8558, Val Loss: 189.1828
# Hyperparameter set 3/20, Fold 3/5, Epoch 60/200, Loss: 176.0128, Val Loss: 165.4907
# Hyperparameter set 3/20, Fold 3/5, Epoch 70/200, Loss: 150.0298, Val Loss: 143.2280
# Hyperparameter set 3/20, Fold 3/5, Epoch 80/200, Loss: 125.1423, Val Loss: 118.7715
# Hyperparameter set 3/20, Fold 3/5, Epoch 90/200, Loss: 102.5590, Val Loss: 99.9215
# Hyperparameter set 3/20, Fold 3/5, Epoch 100/200, Loss: 82.2412, Val Loss: 81.1754
# Hyperparameter set 3/20, Fold 3/5, Epoch 110/200, Loss: 67.3651, Val Loss: 64.4958
# Hyperparameter set 3/20, Fold 3/5, Epoch 120/200, Loss: 54.3527, Val Loss: 50.5472
# Hyperparameter set 3/20, Fold 3/5, Epoch 130/200, Loss: 45.0955, Val Loss: 37.9878
# Hyperparameter set 3/20, Fold 3/5, Epoch 140/200, Loss: 39.0129, Val Loss: 32.6131
# Hyperparameter set 3/20, Fold 3/5, Epoch 150/200, Loss: 34.7137, Val Loss: 28.1130
# Hyperparameter set 3/20, Fold 3/5, Epoch 160/200, Loss: 33.7126, Val Loss: 24.1237
# Hyperparameter set 3/20, Fold 3/5, Epoch 170/200, Loss: 31.0302, Val Loss: 22.5875
# Hyperparameter set 3/20, Fold 3/5, Epoch 180/200, Loss: 30.6872, Val Loss: 20.0071
# Hyperparameter set 3/20, Fold 3/5, Epoch 190/200, Loss: 30.8405, Val Loss: 19.7438
# Hyperparameter set 3/20, Fold 3/5, Epoch 200/200, Loss: 29.4614, Val Loss: 18.5723
# Starting fold 4/5 for hyperparameter set 3/20
# Hyperparameter set 3/20, Fold 4/5, Epoch 10/200, Loss: 297.2141, Val Loss: 291.0047
# Hyperparameter set 3/20, Fold 4/5, Epoch 20/200, Loss: 280.5608, Val Loss: 270.5249
# Hyperparameter set 3/20, Fold 4/5, Epoch 30/200, Loss: 262.8731, Val Loss: 252.2527
# Hyperparameter set 5/20, Fold 2/5, Epoch 110/200, Loss: 41.1310, Val Loss: 23.1240
# Hyperparameter set 5/20, Fold 2/5, Epoch 120/200, Loss: 39.5668, Val Loss: 22.7085
# Hyperparameter set 5/20, Fold 2/5, Epoch 130/200, Loss: 39.6710, Val Loss: 22.2970
# Hyperparameter set 5/20, Fold 2/5, Epoch 140/200, Loss: 39.4033, Val Loss: 22.2678
# Hyperparameter set 5/20, Fold 2/5, Epoch 150/200, Loss: 38.1192, Val Loss: 21.7798
# Hyperparameter set 5/20, Fold 2/5, Epoch 160/200, Loss: 38.3219, Val Loss: 21.5619
# Hyperparameter set 5/20, Fold 2/5, Epoch 170/200, Loss: 38.5606, Val Loss: 21.5777
# Early stopping at epoch 171
# Starting fold 3/5 for hyperparameter set 5/20
# Hyperparameter set 5/20, Fold 3/5, Epoch 10/200, Loss: 201.2066, Val Loss: 146.1077
# Hyperparameter set 5/20, Fold 3/5, Epoch 20/200, Loss: 107.8601, Val Loss: 64.0474
# Hyperparameter set 5/20, Fold 3/5, Epoch 30/200, Loss: 58.3949, Val Loss: 41.4479
# Hyperparameter set 5/20, Fold 3/5, Epoch 40/200, Loss: 50.1358, Val Loss: 32.4738
# Hyperparameter set 5/20, Fold 3/5, Epoch 50/200, Loss: 44.5387, Val Loss: 29.2547
# Hyperparameter set 5/20, Fold 3/5, Epoch 60/200, Loss: 43.8561, Val Loss: 28.4678
# Hyperparameter set 5/20, Fold 3/5, Epoch 70/200, Loss: 42.1224, Val Loss: 27.4302
# Hyperparameter set 5/20, Fold 3/5, Epoch 80/200, Loss: 43.8090, Val Loss: 26.7890
# Hyperparameter set 5/20, Fold 3/5, Epoch 90/200, Loss: 41.4057, Val Loss: 25.9478
# Hyperparameter set 5/20, Fold 3/5, Epoch 100/200, Loss: 40.8429, Val Loss: 25.4668
# Hyperparameter set 5/20, Fold 3/5, Epoch 110/200, Loss: 40.7304, Val Loss: 24.8799
# Hyperparameter set 5/20, Fold 3/5, Epoch 120/200, Loss: 41.0981, Val Loss: 24.3846
# Hyperparameter set 5/20, Fold 3/5, Epoch 130/200, Loss: 41.4356, Val Loss: 23.8563
# Hyperparameter set 5/20, Fold 3/5, Epoch 140/200, Loss: 40.1825, Val Loss: 23.4444
# Hyperparameter set 5/20, Fold 3/5, Epoch 150/200, Loss: 40.3563, Val Loss: 23.0941
# Hyperparameter set 5/20, Fold 3/5, Epoch 160/200, Loss: 39.8600, Val Loss: 22.7709
# Hyperparameter set 5/20, Fold 3/5, Epoch 170/200, Loss: 37.6318, Val Loss: 22.1438
# Hyperparameter set 5/20, Fold 3/5, Epoch 180/200, Loss: 37.5438, Val Loss: 21.8307
# Hyperparameter set 5/20, Fold 3/5, Epoch 190/200, Loss: 38.2024, Val Loss: 21.7512
# Hyperparameter set 5/20, Fold 3/5, Epoch 200/200, Loss: 36.6361, Val Loss: 21.2594
# Starting fold 4/5 for hyperparameter set 5/20
# Hyperparameter set 5/20, Fold 4/5, Epoch 10/200, Loss: 191.5023, Val Loss: 132.9788
# Hyperparameter set 5/20, Fold 4/5, Epoch 20/200, Loss: 100.1812, Val Loss: 65.2294
# Hyperparameter set 5/20, Fold 4/5, Epoch 30/200, Loss: 56.7861, Val Loss: 42.5253
# Hyperparameter set 5/20, Fold 4/5, Epoch 40/200, Loss: 49.9511, Val Loss: 33.0359
# Hyperparameter set 5/20, Fold 4/5, Epoch 50/200, Loss: 46.4617, Val Loss: 34.1544
# Hyperparameter set 5/20, Fold 4/5, Epoch 60/200, Loss: 43.6370, Val Loss: 29.2981
# Hyperparameter set 5/20, Fold 4/5, Epoch 70/200, Loss: 42.9553, Val Loss: 28.2661
# Hyperparameter set 5/20, Fold 4/5, Epoch 80/200, Loss: 42.5030, Val Loss: 27.4042
# Hyperparameter set 5/20, Fold 4/5, Epoch 90/200, Loss: 43.2011, Val Loss: 26.4961
# Hyperparameter set 5/20, Fold 4/5, Epoch 100/200, Loss: 41.0797, Val Loss: 25.7514
# Hyperparameter set 5/20, Fold 4/5, Epoch 110/200, Loss: 40.8652, Val Loss: 25.3956
# Hyperparameter set 5/20, Fold 4/5, Epoch 120/200, Loss: 39.9899, Val Loss: 24.8581
# Hyperparameter set 5/20, Fold 4/5, Epoch 130/200, Loss: 37.9955, Val Loss: 24.3930
# Hyperparameter set 5/20, Fold 4/5, Epoch 140/200, Loss: 38.9551, Val Loss: 24.0361
# Hyperparameter set 5/20, Fold 4/5, Epoch 150/200, Loss: 38.5144, Val Loss: 23.6751
# Hyperparameter set 5/20, Fold 4/5, Epoch 160/200, Loss: 38.3644, Val Loss: 23.2138
# Hyperparameter set 5/20, Fold 4/5, Epoch 170/200, Loss: 37.4400, Val Loss: 22.9733
# Hyperparameter set 5/20, Fold 4/5, Epoch 180/200, Loss: 39.1565, Val Loss: 22.7963
# Hyperparameter set 5/20, Fold 4/5, Epoch 190/200, Loss: 37.6584, Val Loss: 22.6994
# Hyperparameter set 5/20, Fold 4/5, Epoch 200/200, Loss: 38.6709, Val Loss: 22.6752
# Starting fold 5/5 for hyperparameter set 5/20
# Hyperparameter set 5/20, Fold 5/5, Epoch 10/200, Loss: 208.3719, Val Loss: 148.0737
# Hyperparameter set 5/20, Fold 5/5, Epoch 20/200, Loss: 116.3525, Val Loss: 65.8745
# Hyperparameter set 5/20, Fold 5/5, Epoch 30/200, Loss: 62.1064, Val Loss: 42.7279
# Hyperparameter set 5/20, Fold 5/5, Epoch 40/200, Loss: 50.4839, Val Loss: 33.6767
# Hyperparameter set 5/20, Fold 5/5, Epoch 50/200, Loss: 47.9699, Val Loss: 34.0571
# Early stopping at epoch 56
# Average loss for hyperparameter set 5/20: 24.7918
# Starting hyperparameter set 6/20: {'lr': 0.001, 'weight_decay': 0.001, 'hidden1': 64, 'hidden2': 64, 'dropout': 0.5, 'num_epochs': 200}
# Starting fold 1/5 for hyperparameter set 6/20
# Hyperparameter set 6/20, Fold 1/5, Epoch 10/200, Loss: 299.3639, Val Loss: 302.7474
# Hyperparameter set 6/20, Fold 2/5, Epoch 110/200, Loss: 156.0238, Val Loss: 150.8986
# Hyperparameter set 6/20, Fold 2/5, Epoch 120/200, Loss: 144.8025, Val Loss: 139.1713
# Hyperparameter set 6/20, Fold 2/5, Epoch 130/200, Loss: 135.2100, Val Loss: 130.1572
# Hyperparameter set 6/20, Fold 2/5, Epoch 140/200, Loss: 124.9161, Val Loss: 120.3515
# Hyperparameter set 6/20, Fold 2/5, Epoch 150/200, Loss: 116.5917, Val Loss: 111.4828
# Hyperparameter set 6/20, Fold 2/5, Epoch 160/200, Loss: 107.9309, Val Loss: 103.2600
# Hyperparameter set 6/20, Fold 2/5, Epoch 170/200, Loss: 99.6051, Val Loss: 94.5055
# Hyperparameter set 6/20, Fold 2/5, Epoch 180/200, Loss: 92.5351, Val Loss: 87.7729
# Hyperparameter set 6/20, Fold 2/5, Epoch 190/200, Loss: 84.8143, Val Loss: 82.5632
# Hyperparameter set 6/20, Fold 2/5, Epoch 200/200, Loss: 79.4011, Val Loss: 77.2573
# Starting fold 3/5 for hyperparameter set 6/20
# Hyperparameter set 6/20, Fold 3/5, Epoch 10/200, Loss: 295.5145, Val Loss: 301.1699
# Hyperparameter set 6/20, Fold 3/5, Epoch 20/200, Loss: 278.9329, Val Loss: 280.1902
# Hyperparameter set 6/20, Fold 3/5, Epoch 30/200, Loss: 262.8836, Val Loss: 256.3410
# Hyperparameter set 6/20, Fold 3/5, Epoch 40/200, Loss: 248.6969, Val Loss: 238.5920
# Hyperparameter set 6/20, Fold 3/5, Epoch 50/200, Loss: 235.3119, Val Loss: 226.9806
# Hyperparameter set 6/20, Fold 3/5, Epoch 60/200, Loss: 221.9567, Val Loss: 216.3395
# Hyperparameter set 6/20, Fold 3/5, Epoch 70/200, Loss: 209.7547, Val Loss: 204.0410
# Hyperparameter set 6/20, Fold 3/5, Epoch 80/200, Loss: 197.4781, Val Loss: 191.3970
# Hyperparameter set 6/20, Fold 3/5, Epoch 90/200, Loss: 183.8434, Val Loss: 178.4418
# Hyperparameter set 6/20, Fold 3/5, Epoch 100/200, Loss: 173.1435, Val Loss: 165.9133
# Hyperparameter set 6/20, Fold 3/5, Epoch 110/200, Loss: 161.2379, Val Loss: 154.2716
# Hyperparameter set 6/20, Fold 3/5, Epoch 120/200, Loss: 150.4148, Val Loss: 142.1925
# Hyperparameter set 6/20, Fold 3/5, Epoch 130/200, Loss: 138.6591, Val Loss: 132.4812
# Hyperparameter set 6/20, Fold 3/5, Epoch 140/200, Loss: 129.1700, Val Loss: 123.2059
# Hyperparameter set 6/20, Fold 3/5, Epoch 150/200, Loss: 119.8403, Val Loss: 115.3579
# Hyperparameter set 6/20, Fold 3/5, Epoch 160/200, Loss: 110.8998, Val Loss: 107.0549
# Hyperparameter set 6/20, Fold 3/5, Epoch 170/200, Loss: 102.2071, Val Loss: 99.5211
# Hyperparameter set 6/20, Fold 3/5, Epoch 180/200, Loss: 95.4953, Val Loss: 91.4053
# Hyperparameter set 20/20, Fold 1/5, Epoch 90/200, Loss: 96.5734, Val Loss: 82.9432
# Hyperparameter set 20/20, Fold 1/5, Epoch 100/200, Loss: 77.4377, Val Loss: 68.9554
# Hyperparameter set 20/20, Fold 1/5, Epoch 110/200, Loss: 61.0765, Val Loss: 51.4701
# Hyperparameter set 20/20, Fold 1/5, Epoch 120/200, Loss: 49.0017, Val Loss: 38.7435
# Hyperparameter set 20/20, Fold 1/5, Epoch 130/200, Loss: 40.4333, Val Loss: 31.8156
# Hyperparameter set 20/20, Fold 1/5, Epoch 140/200, Loss: 34.8501, Val Loss: 27.0340
# Hyperparameter set 20/20, Fold 1/5, Epoch 150/200, Loss: 31.6563, Val Loss: 22.6137
# Hyperparameter set 20/20, Fold 1/5, Epoch 160/200, Loss: 28.8974, Val Loss: 20.1846
# Hyperparameter set 20/20, Fold 1/5, Epoch 170/200, Loss: 26.9263, Val Loss: 18.9493
# Hyperparameter set 20/20, Fold 1/5, Epoch 180/200, Loss: 26.3599, Val Loss: 15.5839
# Hyperparameter set 20/20, Fold 1/5, Epoch 190/200, Loss: 25.8520, Val Loss: 14.3130
# Hyperparameter set 20/20, Fold 1/5, Epoch 200/200, Loss: 25.0210, Val Loss: 13.0698
# Starting fold 2/5 for hyperparameter set 20/20
# Hyperparameter set 20/20, Fold 2/5, Epoch 10/200, Loss: 293.5209, Val Loss: 279.2954
# Hyperparameter set 20/20, Fold 2/5, Epoch 20/200, Loss: 275.0191, Val Loss: 256.2001
# Hyperparameter set 20/20, Fold 2/5, Epoch 30/200, Loss: 255.5555, Val Loss: 242.8328
# Hyperparameter set 20/20, Fold 2/5, Epoch 40/200, Loss: 233.1724, Val Loss: 217.4979
# Hyperparameter set 20/20, Fold 2/5, Epoch 50/200, Loss: 208.1902, Val Loss: 195.7975
# Hyperparameter set 20/20, Fold 2/5, Epoch 60/200, Loss: 182.0817, Val Loss: 173.7170
# Hyperparameter set 20/20, Fold 2/5, Epoch 70/200, Loss: 154.8060, Val Loss: 147.7743
# Hyperparameter set 20/20, Fold 2/5, Epoch 80/200, Loss: 128.0617, Val Loss: 129.9348
# Hyperparameter set 20/20, Fold 2/5, Epoch 90/200, Loss: 104.0733, Val Loss: 99.3705
# Hyperparameter set 20/20, Fold 2/5, Epoch 100/200, Loss: 80.1361, Val Loss: 73.3764
# Hyperparameter set 20/20, Fold 2/5, Epoch 110/200, Loss: 62.0294, Val Loss: 52.1274
# Hyperparameter set 20/20, Fold 2/5, Epoch 120/200, Loss: 48.1438, Val Loss: 42.8232
# Hyperparameter set 20/20, Fold 2/5, Epoch 130/200, Loss: 39.8138, Val Loss: 32.3366
# Hyperparameter set 20/20, Fold 2/5, Epoch 140/200, Loss: 32.6378, Val Loss: 25.7209
# Hyperparameter set 20/20, Fold 2/5, Epoch 150/200, Loss: 29.9145, Val Loss: 22.3742
# Hyperparameter set 20/20, Fold 2/5, Epoch 160/200, Loss: 28.3663, Val Loss: 18.1833
# Hyperparameter set 20/20, Fold 2/5, Epoch 170/200, Loss: 27.0064, Val Loss: 17.2831
# Hyperparameter set 20/20, Fold 2/5, Epoch 180/200, Loss: 26.7252, Val Loss: 14.8236
# Hyperparameter set 20/20, Fold 2/5, Epoch 190/200, Loss: 25.8491, Val Loss: 13.9338
# Hyperparameter set 20/20, Fold 2/5, Epoch 200/200, Loss: 25.9539, Val Loss: 13.8444
# Starting fold 3/5 for hyperparameter set 20/20
# Hyperparameter set 20/20, Fold 3/5, Epoch 10/200, Loss: 281.3953, Val Loss: 260.3852
# Hyperparameter set 20/20, Fold 3/5, Epoch 20/200, Loss: 260.4909, Val Loss: 240.4955
# Hyperparameter set 20/20, Fold 3/5, Epoch 30/200, Loss: 238.7007, Val Loss: 218.7640
# Hyperparameter set 20/20, Fold 3/5, Epoch 40/200, Loss: 215.0645, Val Loss: 195.6627
# Hyperparameter set 20/20, Fold 3/5, Epoch 50/200, Loss: 190.6416, Val Loss: 178.6753
# Hyperparameter set 20/20, Fold 3/5, Epoch 60/200, Loss: 164.3777, Val Loss: 156.3633
# Hyperparameter set 20/20, Fold 3/5, Epoch 70/200, Loss: 139.8945, Val Loss: 136.8042
# Hyperparameter set 20/20, Fold 3/5, Epoch 80/200, Loss: 114.9063, Val Loss: 108.5250
# Hyperparameter set 20/20, Fold 3/5, Epoch 90/200, Loss: 92.7025, Val Loss: 92.1277
# Hyperparameter set 20/20, Fold 3/5, Epoch 100/200, Loss: 73.6694, Val Loss: 71.0778
# Hyperparameter set 20/20, Fold 3/5, Epoch 110/200, Loss: 57.5468, Val Loss: 60.7450
# Hyperparameter set 20/20, Fold 3/5, Epoch 120/200, Loss: 45.8410, Val Loss: 46.9275
# Hyperparameter set 20/20, Fold 3/5, Epoch 130/200, Loss: 38.8840, Val Loss: 36.7172
# Hyperparameter set 20/20, Fold 3/5, Epoch 140/200, Loss: 33.5455, Val Loss: 27.5833
# Hyperparameter set 20/20, Fold 3/5, Epoch 150/200, Loss: 30.6300, Val Loss: 22.6572
# Hyperparameter set 20/20, Fold 3/5, Epoch 160/200, Loss: 28.3155, Val Loss: 20.0439
# Hyperparameter set 20/20, Fold 3/5, Epoch 170/200, Loss: 27.7354, Val Loss: 18.8324
# Hyperparameter set 20/20, Fold 3/5, Epoch 180/200, Loss: 26.7492, Val Loss: 16.1194
# Hyperparameter set 20/20, Fold 3/5, Epoch 190/200, Loss: 26.3218, Val Loss: 14.7391
# Hyperparameter set 20/20, Fold 3/5, Epoch 200/200, Loss: 26.9377, Val Loss: 14.5197
# Starting fold 4/5 for hyperparameter set 20/20
# Hyperparameter set 20/20, Fold 4/5, Epoch 10/200, Loss: 287.8112, Val Loss: 276.4302
# Hyperparameter set 20/20, Fold 4/5, Epoch 20/200, Loss: 272.1604, Val Loss: 261.9535
# Hyperparameter set 20/20, Fold 4/5, Epoch 30/200, Loss: 255.9551, Val Loss: 245.9397
# Hyperparameter set 20/20, Fold 4/5, Epoch 40/200, Loss: 234.5922, Val Loss: 224.3327
# Hyperparameter set 20/20, Fold 4/5, Epoch 50/200, Loss: 209.4985, Val Loss: 198.5506
# Hyperparameter set 20/20, Fold 4/5, Epoch 60/200, Loss: 183.7024, Val Loss: 170.4534
# Hyperparameter set 20/20, Fold 4/5, Epoch 70/200, Loss: 154.9804, Val Loss: 145.4421
# Hyperparameter set 20/20, Fold 4/5, Epoch 80/200, Loss: 128.2209, Val Loss: 117.8325
# Hyperparameter set 20/20, Fold 4/5, Epoch 90/200, Loss: 103.3827, Val Loss: 92.8731
# Hyperparameter set 20/20, Fold 4/5, Epoch 100/200, Loss: 81.2302, Val Loss: 70.6807
# Hyperparameter set 20/20, Fold 4/5, Epoch 110/200, Loss: 63.6459, Val Loss: 54.0207
# Hyperparameter set 20/20, Fold 4/5, Epoch 120/200, Loss: 50.4282, Val Loss: 42.1655
# Hyperparameter set 20/20, Fold 4/5, Epoch 130/200, Loss: 39.0243, Val Loss: 33.1618
# Hyperparameter set 20/20, Fold 4/5, Epoch 140/200, Loss: 33.6298, Val Loss: 24.9408
# Hyperparameter set 20/20, Fold 4/5, Epoch 150/200, Loss: 28.9112, Val Loss: 20.8516
# Hyperparameter set 20/20, Fold 4/5, Epoch 160/200, Loss: 28.2545, Val Loss: 17.1958
# Hyperparameter set 20/20, Fold 4/5, Epoch 170/200, Loss: 26.1672, Val Loss: 15.9896
# Hyperparameter set 20/20, Fold 4/5, Epoch 180/200, Loss: 24.8017, Val Loss: 15.5145
# Hyperparameter set 20/20, Fold 4/5, Epoch 190/200, Loss: 25.0238, Val Loss: 13.8226
# Hyperparameter set 20/20, Fold 4/5, Epoch 200/200, Loss: 25.0711, Val Loss: 12.9167
# Starting fold 5/5 for hyperparameter set 20/20
# Hyperparameter set 20/20, Fold 5/5, Epoch 10/200, Loss: 281.5874, Val Loss: 269.3399
# Hyperparameter set 20/20, Fold 5/5, Epoch 20/200, Loss: 263.8788, Val Loss: 248.6575
# Hyperparameter set 20/20, Fold 5/5, Epoch 30/200, Loss: 246.1861, Val Loss: 230.1420
# Hyperparameter set 20/20, Fold 5/5, Epoch 40/200, Loss: 225.4030, Val Loss: 209.4796
# Hyperparameter set 20/20, Fold 5/5, Epoch 50/200, Loss: 204.8579, Val Loss: 193.8529
# Hyperparameter set 20/20, Fold 5/5, Epoch 60/200, Loss: 183.2495, Val Loss: 173.3178
# Hyperparameter set 20/20, Fold 5/5, Epoch 70/200, Loss: 159.2013, Val Loss: 154.2522
# Hyperparameter set 20/20, Fold 5/5, Epoch 80/200, Loss: 133.3299, Val Loss: 122.6225
# Hyperparameter set 20/20, Fold 5/5, Epoch 90/200, Loss: 110.3592, Val Loss: 104.8508
# Hyperparameter set 20/20, Fold 5/5, Epoch 100/200, Loss: 88.4077, Val Loss: 79.2298
# Hyperparameter set 20/20, Fold 5/5, Epoch 110/200, Loss: 66.7260, Val Loss: 62.9270
# Hyperparameter set 20/20, Fold 5/5, Epoch 120/200, Loss: 52.1292, Val Loss: 45.9821
# Hyperparameter set 20/20, Fold 5/5, Epoch 130/200, Loss: 42.0249, Val Loss: 33.5446
# Fold 5/5, Epoch 170/200, Loss: 26.8033, Val Loss: 18.1330
# Fold 5/5, Epoch 180/200, Loss: 24.7682, Val Loss: 15.4471
# Fold 5/5, Epoch 190/200, Loss: 24.6507, Val Loss: 14.7906
# Fold 5/5, Epoch 200/200, Loss: 23.1791, Val Loss: 13.2145
# Fold 5 results - MSE: 16.4828, RMSE: 4.0599, MAE: 2.9914, R²: 0.7999
# Fold 1 - MSE: 16.2637, RMSE: 4.0328, MAE: 3.0086, R²: 0.8017
# Fold 2 - MSE: 14.0137, RMSE: 3.7435, MAE: 2.7670, R²: 0.8318
# Fold 3 - MSE: 19.4469, RMSE: 4.4099, MAE: 3.2412, R²: 0.7701
# Fold 4 - MSE: 19.1823, RMSE: 4.3798, MAE: 3.1962, R²: 0.7679
# Fold 5 - MSE: 16.4828, RMSE: 4.0599, MAE: 2.9914, R²: 0.7999
# Average - MSE: 17.0779, RMSE: 4.1252, MAE: 3.0409, R²: 0.7943

# %%
best_params
# Out:
# {'lr': 0.005,
#  'weight_decay': 0.001,
#  'hidden1': 128,
#  'hidden2': 16,
#  'dropout': 0.3,
#  'num_epochs': 200}

# %%
import torch
from torch_geometric.utils import k_hop_subgraph
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch.nn.functional as F
from torch_geometric.nn import GATv2Conv
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 定义GATv2模型
class GATv2(torch.nn.Module):
    def __init__(self, in_channels, hidden1, hidden2, out_channels, dropout):
        super(GATv2, self).__init__()
        self.conv1 = GATv2Conv(in_channels, hidden1, heads=1)
        self.bn1 = torch.nn.BatchNorm1d(hidden1)  # Batch normalization
        self.conv2 = GATv2Conv(hidden1, hidden2, heads=1)
        self.bn2 = torch.nn.BatchNorm1d(hidden2)  # Batch normalization
        self.fc1 = torch.nn.Linear(hidden2, out_channels)
        self.dropout = dropout

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = self.bn1(x)  # Batch normalization
        x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)  # Dropout
        x = self.conv2(x, edge_index)
        x = self.bn2(x)  # Batch normalization
        x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)  # Dropout
        x = self.fc1(x)
        return x

def train(model, optimizer, data):
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index)
    loss = F.mse_loss(out, data.y)
    loss.backward()
    optimizer.step()
    return loss.item()

def evaluate(model, data):
    model.eval()
    with torch.no_grad():
        out = model(data.x, data.edge_index)
        loss = F.mse_loss(out, data.y).item()
    return loss

# 定义早停机制
class EarlyStopping:
    def __init__(self, patience=10, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = float('inf')
        self.counter = 0

    def step(self, loss):
        if loss < self.best_loss - self.min_delta:
            self.best_loss = loss
            self.counter = 0
        else:
            self.counter += 1

        return self.counter >= self.patience

# 定义创建子图的函数，包括边界节点
def create_subgraph(data, train_idx, test_idx, num_hops):
    train_idx = torch.tensor(train_idx, dtype=torch.long, device=data.edge_index.device)
    test_idx = torch.tensor(test_idx, dtype=torch.long, device=data.edge_index.device)
    
    # 获取训练集子图，包含 train_idx 节点以及 num_hops 范围内的邻居
    train_subgraph = k_hop_subgraph(train_idx, num_hops, data.edge_index, relabel_nodes=True)
    train_edge_index, train_x, train_y = train_subgraph[1], data.x[train_subgraph[0]], data.y[train_subgraph[0]]
    
    # 获取测试集子图，包含 test_idx 节点以及 num_hops 范围内的邻居
    test_subgraph = k_hop_subgraph(test_idx, num_hops, data.edge_index, relabel_nodes=True)
    test_edge_index, test_x, test_y = test_subgraph[1], data.x[test_subgraph[0]], data.y[test_subgraph[0]]
    
    return (train_x, train_edge_index, train_y), (test_x, test_edge_index, test_y)

# 使用最佳参数重新训练模型并评估
def evaluate_leave_one_out(data, best_params, region_mask, num_hops=2):
    # 提取特定区域节点
    test_idx = torch.where(region_mask)[0].numpy()
    train_idx = np.setdiff1d(np.arange(data.num_nodes), test_idx)
    
    # 创建训练和测试子图
    (train_x, train_edge_index, train_y), (test_x, test_edge_index, test_y) = create_subgraph(data, train_idx, test_idx, num_hops)
    
    # 初始化模型和优化器
    model = GATv2(
        in_channels=train_x.shape[1], 
        hidden1=best_params['hidden1'], 
        hidden2=best_params['hidden2'], 
        out_channels=train_y.shape[1], 
        dropout=best_params['dropout']
    )
    optimizer = torch.optim.Adam(model.parameters(), lr=best_params['lr'], weight_decay=best_params['weight_decay'])
    
    # 训练模型
    model.train()
    for epoch in range(best_params['num_epochs']):
        loss = train(model, optimizer, data)
        if (epoch + 1) % 10 == 0:
            print(f'Epoch {epoch + 1}/{best_params["num_epochs"]}, Loss: {loss:.4f}')
    
    # 测试模型
    model.eval()
    with torch.no_grad():
        pred = model(test_x, test_edge_index)
        y_true = test_y.numpy()
        y_pred = pred.numpy()
        
        mse = mean_squared_error(y_true, y_pred)
        rmse = np.sqrt(mse)
        mae = mean_absolute_error(y_true, y_pred)
        r2 = r2_score(y_true, y_pred)
    
    print(f'Test results - MSE: {mse:.4f}, RMSE: {rmse:.4f}, MAE: {mae:.4f}, R²: {r2:.4f}')
    
    # 绘制残差图
    residuals = y_true - y_pred
    plt.figure(figsize=(10, 5))
    plt.hist(residuals, bins=50, alpha=0.75)
    plt.xlabel('Residual')
    plt.ylabel('Frequency')
    plt.title('Histogram of Residuals')
    plt.show()
    
    return mse, rmse, mae, r2

# 假设你已经有一个数据对象 data 和最佳参数 best_params
# data = ...
# best_params = ...

# 加载或创建GeoDataFrame gdf，这里假设gdf包含了每个节点的地理信息
# gdf = ...

# 假设LSOA21NM是GeoDataFrame中表示区域名称的列，并且我们要提取Southwark区域
region_name = 'Southwark'
region_mask = gdf['LSOA21NM'].str.contains(region_name)

# 将GeoDataFrame中的索引与图中的节点索引对齐，创建region_mask
region_mask = torch.tensor(region_mask.values, dtype=torch.bool, device=data.edge_index.device)

# 使用最佳参数重新训练模型并在特定区域上测试
mse, rmse, mae, r2 = evaluate_leave_one_out(data, best_params, region_mask)
# Out:
# Epoch 10/200, Loss: 291.5773
# Epoch 20/200, Loss: 274.1528
# Epoch 30/200, Loss: 256.0388
# Epoch 40/200, Loss: 235.5541
# Epoch 50/200, Loss: 213.0841
# Epoch 60/200, Loss: 186.1399
# Epoch 70/200, Loss: 157.5205
# Epoch 80/200, Loss: 130.4952
# Epoch 90/200, Loss: 106.1050
# Epoch 100/200, Loss: 81.7449
# Epoch 110/200, Loss: 65.6712
# Epoch 120/200, Loss: 49.8237
# Epoch 130/200, Loss: 41.3059
# Epoch 140/200, Loss: 34.6704
# Epoch 150/200, Loss: 31.3686
# Epoch 160/200, Loss: 28.9315
# Epoch 170/200, Loss: 26.7211
# Epoch 180/200, Loss: 24.4865
# Epoch 190/200, Loss: 24.1517
# Epoch 200/200, Loss: 22.8350
# Test results - MSE: 17.1618, RMSE: 4.1427, MAE: 3.3931, R²: 0.6858

# %%
import torch
from torch_geometric.utils import k_hop_subgraph
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch.nn.functional as F
from torch_geometric.nn import GATv2Conv
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 定义GATv2模型
class GATv2(torch.nn.Module):
    def __init__(self, in_channels, hidden1, hidden2, out_channels, dropout):
        super(GATv2, self).__init__()
        self.conv1 = GATv2Conv(in_channels, hidden1, heads=1)
        self.bn1 = torch.nn.BatchNorm1d(hidden1)  # Batch normalization
        self.conv2 = GATv2Conv(hidden1, hidden2, heads=1)
        self.bn2 = torch.nn.BatchNorm1d(hidden2)  # Batch normalization
        self.fc1 = torch.nn.Linear(hidden2, out_channels)
        self.dropout = dropout

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = self.bn1(x)  # Batch normalization
        x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)  # Dropout
        x = self.conv2(x, edge_index)
        x = self.bn2(x)  # Batch normalization
        x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)  # Dropout
        x = self.fc1(x)
        return x

def train(model, optimizer, data):
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index)
    loss = F.mse_loss(out, data.y)
    loss.backward()
    optimizer.step()
    return loss.item()

def evaluate(model, data):
    model.eval()
    with torch.no_grad():
        out = model(data.x, data.edge_index)
        loss = F.mse_loss(out, data.y).item()
    return loss

# 定义早停机制
class EarlyStopping:
    def __init__(self, patience=10, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = float('inf')
        self.counter = 0

    def step(self, loss):
        if loss < self.best_loss - self.min_delta:
            self.best_loss = loss
            self.counter = 0
        else:
            self.counter += 1

        return self.counter >= self.patience

# 定义创建子图的函数，包括边界节点
def create_subgraph(data, train_idx, test_idx, num_hops):
    train_idx = torch.tensor(train_idx, dtype=torch.long, device=data.edge_index.device)
    test_idx = torch.tensor(test_idx, dtype=torch.long, device=data.edge_index.device)
    
    # 获取训练集子图，包含 train_idx 节点以及 num_hops 范围内的邻居
    train_subgraph = k_hop_subgraph(train_idx, num_hops, data.edge_index, relabel_nodes=True)
    train_edge_index, train_x, train_y = train_subgraph[1], data.x[train_subgraph[0]], data.y[train_subgraph[0]]
    
    # 获取测试集子图，包含 test_idx 节点以及 num_hops 范围内的邻居
    test_subgraph = k_hop_subgraph(test_idx, num_hops, data.edge_index, relabel_nodes=True)
    test_edge_index, test_x, test_y = test_subgraph[1], data.x[test_subgraph[0]], data.y[test_subgraph[0]]
    
    return (train_x, train_edge_index, train_y), (test_x, test_edge_index, test_y)

# 使用最佳参数重新训练模型并评估
def evaluate_leave_one_out(data, best_params, region_mask, num_hops=2):
    # 提取特定区域节点
    test_idx = torch.where(region_mask)[0].numpy()
    train_idx = np.setdiff1d(np.arange(data.num_nodes), test_idx)
    
    # 创建训练和测试子图
    (train_x, train_edge_index, train_y), (test_x, test_edge_index, test_y) = create_subgraph(data, train_idx, test_idx, num_hops)
    
    # 初始化模型和优化器
    model = GATv2(
        in_channels=train_x.shape[1], 
        hidden1=best_params['hidden1'], 
        hidden2=best_params['hidden2'], 
        out_channels=train_y.shape[1], 
        dropout=best_params['dropout']
    )
    optimizer = torch.optim.Adam(model.parameters(), lr=best_params['lr'], weight_decay=best_params['weight_decay'])
    
    # 训练模型
    model.train()
    for epoch in range(best_params['num_epochs']):
        loss = train(model, optimizer, data)
        if (epoch + 1) % 10 == 0:
            print(f'Epoch {epoch + 1}/{best_params["num_epochs"]}, Loss: {loss:.4f}')
    
    # 测试模型
    model.eval()
    with torch.no_grad():
        pred = model(test_x, test_edge_index)
        y_true = test_y.numpy()
        y_pred = pred.numpy()
        
        mse = mean_squared_error(y_true, y_pred)
        rmse = np.sqrt(mse)
        mae = mean_absolute_error(y_true, y_pred)
        r2 = r2_score(y_true, y_pred)
    
    print(f'Test results - MSE: {mse:.4f}, RMSE: {rmse:.4f}, MAE: {mae:.4f}, R²: {r2:.4f}')
    
    # 绘制残差图
    residuals = y_true - y_pred
    plt.figure(figsize=(10, 5))
    plt.hist(residuals, bins=50, alpha=0.75)
    plt.xlabel('Residual')
    plt.ylabel('Frequency')
    plt.title('Histogram of Residuals')
    plt.show()
    
    return mse, rmse, mae, r2

# 假设你已经有一个数据对象 data 和最佳参数 best_params
# data = ...
# best_params = ...

# 加载或创建GeoDataFrame gdf，这里假设gdf包含了每个节点的地理信息
# gdf = ...

# 假设LSOA21NM是GeoDataFrame中表示区域名称的列，并且我们要提取Southwark区域
region_name = 'Barking'
region_mask = gdf['LSOA21NM'].str.contains(region_name)

# 将GeoDataFrame中的索引与图中的节点索引对齐，创建region_mask
region_mask = torch.tensor(region_mask.values, dtype=torch.bool, device=data.edge_index.device)

# 使用最佳参数重新训练模型并在特定区域上测试
mse, rmse, mae, r2 = evaluate_leave_one_out(data, best_params, region_mask)
# Out:
# Epoch 10/200, Loss: 307.6649
# Epoch 20/200, Loss: 293.7681
# Epoch 30/200, Loss: 279.8307
# Epoch 40/200, Loss: 265.4702
# Epoch 50/200, Loss: 247.7393
# Epoch 60/200, Loss: 225.9639
# Epoch 70/200, Loss: 198.8463
# Epoch 80/200, Loss: 170.1722
# Epoch 90/200, Loss: 141.7085
# Epoch 100/200, Loss: 114.8147
# Epoch 110/200, Loss: 93.5004
# Epoch 120/200, Loss: 75.8959
# Epoch 130/200, Loss: 61.1520
# Epoch 140/200, Loss: 51.3650
# Epoch 150/200, Loss: 44.9500
# Epoch 160/200, Loss: 38.5984
# Epoch 170/200, Loss: 33.6519
# Epoch 180/200, Loss: 31.1899
# Epoch 190/200, Loss: 29.3791
# Epoch 200/200, Loss: 28.0969
# Test results - MSE: 13.0527, RMSE: 3.6129, MAE: 2.4549, R²: 0.7974

# %%
model
# Out:
# GATv2(
#   (conv1): GATv2Conv(47, 64, heads=1)
#   (conv2): GATv2Conv(64, 32, heads=1)
#   (fc1): Linear(in_features=32, out_features=1, bias=True)
# )

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GATv2Conv
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import pandas as pd

# 定义GATv2模型
class GATv2(torch.nn.Module):
    def __init__(self, in_channels, hidden1, hidden2, out_channels, dropout):
        super(GATv2, self).__init__()
        self.conv1 = GATv2Conv(in_channels, hidden1, heads=1)
        self.bn1 = torch.nn.BatchNorm1d(hidden1)  # Batch normalization
        self.conv2 = GATv2Conv(hidden1, hidden2, heads=1)
        self.bn2 = torch.nn.BatchNorm1d(hidden2)  # Batch normalization
        self.fc1 = torch.nn.Linear(hidden2, out_channels)
        self.dropout = dropout

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = self.bn1(x)  # Batch normalization
        x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)  # Dropout
        conv1_out = x  # 保存第一层卷积的输出
        x = self.conv2(x, edge_index)
        x = self.bn2(x)  # Batch normalization
        x = F.relu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)  # Dropout
        conv2_out = x  # 保存第二层卷积的输出
        x = self.fc1(x)
        return conv1_out, conv2_out, x

def train(model, optimizer, data):
    model.train()
    optimizer.zero_grad()
    _, _, out = model(data.x, data.edge_index)
    loss = F.mse_loss(out, data.y)
    loss.backward()
    optimizer.step()
    return loss.item()

def train_with_best_params(data, best_params, num_epochs=200):
    model = GATv2(
        in_channels=data.x.shape[1], 
        hidden1=best_params['hidden1'], 
        hidden2=best_params['hidden2'], 
        out_channels=data.y.shape[1], 
        dropout=best_params['dropout']
    )
    optimizer = torch.optim.Adam(model.parameters(), lr=best_params['lr'], weight_decay=best_params['weight_decay'])
    
    losses = []
    for epoch in range(num_epochs):
        loss = train(model, optimizer, data)
        losses.append(loss)
        if (epoch + 1) % 10 == 0:
            print(f'Epoch {epoch + 1}/{num_epochs}, Loss: {loss:.4f}')
    return model, losses

# 使用最佳参数训练模型
# 假设你已经有一个数据对象 data 和最佳参数 best_params
# best_params = {'lr': 0.005, 'weight_decay': 0.001, 'hidden1': 64, 'hidden2': 32, 'dropout': 0.5}
model, losses = train_with_best_params(data, best_params)

# 提取嵌入
model.eval()
with torch.no_grad():
    conv1_out, conv2_out, _ = model(data.x, data.edge_index)
    conv1_embeddings = conv1_out.cpu().numpy()
    conv2_embeddings = conv2_out.cpu().numpy()

# 确保嵌入已定义
print(f"Shape of conv1 embeddings: {conv1_embeddings.shape}")
print(f"Shape of conv2 embeddings: {conv2_embeddings.shape}")

# 确保 n_components 设置正确
pca_components = 1
if min(conv2_embeddings.shape) < pca_components:
    pca_components = min(conv2_embeddings.shape)

# 计算PCA并获取解释方差比
pca = PCA(n_components=pca_components, random_state=0)
pca_result = pca.fit_transform(conv2_embeddings)
explained_variance_ratio = pca.explained_variance_ratio_
print(f"Explained Variance Ratio: {explained_variance_ratio}")

# 计算载荷
loadings = pca.components_.T

# 计算特征贡献度（解释方差比乘以载荷的平方）
contributions = loadings ** 2 * explained_variance_ratio

# 创建贡献度矩阵DataFrame
contribution_matrix = pd.DataFrame(contributions, columns=[f'PCA{i+1}' for i in range(pca_components)])

# 打印每个主成分的前几个变量及其贡献
print("PCA1 Top Contributors:")
print(contribution_matrix['PCA1'].sort_values(ascending=False).head(10))

if pca_components > 1:
    print("\nPCA2 Top Contributors:")
    print(contribution_matrix['PCA2'].sort_values(ascending=False).head(10))

# 可视化每个主成分的前几个变量及其贡献
plt.figure(figsize=(10, 5))
contribution_matrix['PCA1'].sort_values(ascending=False).head(10).plot(kind='bar')
plt.title('Top 10 Contributors to PCA1')
plt.xlabel('Features')
plt.ylabel('Contribution')
plt.show()

if pca_components > 1:
    plt.figure(figsize=(10, 5))
    contribution_matrix['PCA2'].sort_values(ascending=False).head(10).plot(kind='bar')
    plt.title('Top 10 Contributors to PCA2')
    plt.xlabel('Features')
    plt.ylabel('Contribution')
    plt.show()
# Out:
# Epoch 10/200, Loss: 270.4277
# Epoch 20/200, Loss: 249.4815
# Epoch 30/200, Loss: 228.1072
# Epoch 40/200, Loss: 204.9772
# Epoch 50/200, Loss: 180.5430
# Epoch 60/200, Loss: 156.3836
# Epoch 70/200, Loss: 132.2373
# Epoch 80/200, Loss: 110.3487
# Epoch 90/200, Loss: 89.5771
# Epoch 100/200, Loss: 72.5297
# Epoch 110/200, Loss: 59.7619
# Epoch 120/200, Loss: 47.9658
# Epoch 130/200, Loss: 39.5436
# Epoch 140/200, Loss: 33.3811
# Epoch 150/200, Loss: 32.6474
# Epoch 160/200, Loss: 28.9793
# Epoch 170/200, Loss: 25.0623
# Epoch 180/200, Loss: 23.5850
# Epoch 190/200, Loss: 22.7283
# Epoch 200/200, Loss: 22.2419
# Shape of conv1 embeddings: (4994, 128)
# Shape of conv2 embeddings: (4994, 16)
# Explained Variance Ratio: [0.7304571]
# PCA1 Top Contributors:
# 13    0.063430
# 10    0.062583
# 3     0.061805
# 0     0.057268
# 14    0.055191
# 2     0.054206
# 9     0.053900
# 15    0.052596
# 4     0.051858
# 5     0.049943
# Name: PCA1, dtype: float32

# %%
def plot_variable_v2(gdf, variable, variable_name):

    if variable.startswith('e'):
        colormap = colors.LinearSegmentedColormap.from_list('', ['#ffffff', '#c27ba0'])
    elif variable.startswith('o'):
        colormap = colors.LinearSegmentedColormap.from_list('', ['#ffffff', '#6d9eeb'])
    elif variable.startswith('c'):
        colormap = colors.LinearSegmentedColormap.from_list('', ['#ffffff', '#008080'])
    else:
        colormap = 'coolwarm'

    # Parameters to display missing data in black
    missing_data_color = {
        'color': 'black',
        # 'color':'#808080',
        # 'edgecolor': 'black',
        # 'hatch': '///',  # this is optional, if you'd like a hatch pattern for missing data
        'label': 'Missing Data'
    }

    # Plotting the GeoPandas DataFrame
    ax = gdf.plot(column=variable, legend=True, figsize=(15, 10), cmap=colormap, missing_kwds=missing_data_color)

    # Remove the axes
    plt.axis('off')

    # Customize the legend font size
    # Get the color bar object
    cax = plt.gcf().axes[-1]

    # Customize the color bar font size
    cax.tick_params(labelsize=33)

    # Title
    plt.title(variable_name, fontsize=44)

    return plt

# %%
import pandas as pd
import geopandas as gpd
from shapely import wkt

# Read the CSV file
csv_file = 'LondonLSOAs.csv'
df = pd.read_csv(csv_file)

# Convert the 'geometry' column to Shapely geometry objects
df['geometry'] = df['geometry'].apply(wkt.loads)

# Create the GeoDataFrame
gdf_plot = gpd.GeoDataFrame(df, geometry='geometry')

# 将PCA结果添加到GeoDataFrame中
gdf_plot['PCA1'] = pca_result[:, 0]
# gdf_plot['PCA2'] = pca_result[:, 1]
# gdf_plot['PCA3'] = pca_result[:, 2]

# 可视化PCA1和PCA2
plot_variable_v2(gdf_plot, 'PCA1', 'PCA1')
# plot_variable_v2(gdf_plot, 'PCA2', 'PCA2')
# plot_variable_v2(gdf_plot, 'PCA3', 'PCA3')
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\0\\anaconda3\\envs\\envGEOG0051\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GATv2Conv
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from sklearn.preprocessing import StandardScaler
import seaborn as sns
# 提取PCA主成分
pca_df = pd.DataFrame(pca_result, columns=[f'PCA{i+1}' for i in range(pca_components)])

# 读取CSV文件并创建GeoDataFrame
csv_file = 'LondonLSOAs.csv'
df = pd.read_csv(csv_file)

# 创建几何对象（假设geometry列包含WKT格式的多边形数据）
gdf = gpd.GeoDataFrame(df, geometry=gpd.GeoSeries.from_wkt(df['geometry']))

# 设置坐标系 (假设是WGS84坐标系)
gdf.set_crs(epsg=4326, inplace=True)
# 固定选取的变量
fixed_columns = [
    'c_percent Aged 10 to 14 years',
    'c_percent Aged 15 to 19 years',
    'c_percent Aged 20 to 24 years',
    'c_percent Aged 25 to 29 years',
    'c_percent Aged 30 to 34 years',
    'c_percent Aged 35 to 39 years',
    'c_percent Aged 40 to 44 years',
    'c_percent Aged 65 to 69 years',
    'c_percent Aged 70 to 74 years',
    'c_percent Aged 75 to 79 years',
    'c_percent Aged 80 to 84 years',
    'c_percent Aged 85 years and over',
    'c_percent mixed',
    'c_percent white',
    'c_percent 2. Professional occupations',
    'c_pop_density',
    'e_NO2',
    'e_ndvi',
    'e_water',
    'e_trees',
    'e_grass',
    'e_bare',
    'c_percent asian',
    'c_percent black',
    'c_percent buddhist',
    'c_percent muslim',
    'c_percent no central heating',
    'c_percent communal heating',
    'c_percent TFW less than 2km',
    'c_percent 49 or more hours worked',
    'c_percent commute on foot',
    'c_percent commute metro rail',
    'c_percent commute bus',
    'c_percent commute bicycle',
    'c_percent student moved to address',
    'c_percent occupancy rating bedrooms -2',
    'c_percent occupancy rating bedrooms -1',
    # 'c_percent occupancy rating rooms -1',
    'c_percent 10 years or more',
    'c_percent 2 years or more but less than 5 years',
    'c_percent 5 years or more but less than 10 years',
    'c_percent married or in a registered civil partnership married same sex',
    'c_percent married or in a registered civil partnership in a registered civil partnership',
    # 'c_percent married or in a registered civil partnership in a registered civil partnership same sex',
    'c_percent separated but still legally married or still legally in a civil partnership separated but still in a registered civil partnership',
    'c_percent divorced or civil partnership dissolved formerly in a civil partnership now legally dissolved',
    'c_percent   cannot speak english well',
    'c_percent   cannot speak english',
    'c_percent households deprived in four dimensions'
]
# 提取固定变量
fixed_features = gdf[fixed_columns].apply(pd.to_numeric, errors='coerce')

# 标准化固定变量
scaler = StandardScaler()
fixed_features_scaled = scaler.fit_transform(fixed_features)
fixed_features_df = pd.DataFrame(fixed_features_scaled, columns=fixed_columns)

# 计算PCA主成分与固定变量的相关性
correlation_matrix = fixed_features_df.join(pca_df).corr()
pca_corr = correlation_matrix.loc[fixed_columns, [f'PCA{i+1}' for i in range(pca_components)]]

# 打印相关性矩阵
print("Correlation with PCA components:")
print(pca_corr)

# 可视化相关性矩阵
plt.figure(figsize=(10, 8))
sns.heatmap(pca_corr, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation between Fixed Variables and PCA Components')
plt.show()
# Out:
# Correlation with PCA components:
#                                                         PCA1
# c_percent Aged 10 to 14 years                       0.338076
# c_percent Aged 15 to 19 years                       0.060655
# c_percent Aged 20 to 24 years                      -0.473655
# c_percent Aged 25 to 29 years                      -0.587729
# c_percent Aged 30 to 34 years                      -0.520968
# c_percent Aged 35 to 39 years                      -0.269274
# c_percent Aged 40 to 44 years                       0.136102
# c_percent Aged 65 to 69 years                       0.415400
# c_percent Aged 70 to 74 years                       0.479661
# c_percent Aged 75 to 79 years                       0.452555
# c_percent Aged 80 to 84 years                       0.419365
# c_percent Aged 85 years and over                    0.403481
# c_percent mixed                                    -0.205567
# c_percent white                                     0.367980
# c_percent 2. Professional occupations              -0.205140
# c_pop_density                                      -0.538619
# e_NO2                                              -0.734421
# e_ndvi                                              0.491127
# e_water                                            -0.164724
# e_trees                                             0.451771
# e_grass                                             0.289873
# e_bare                                             -0.272933
# c_percent asian                                    -0.188942
# c_percent black                                    -0.193941
# c_percent buddhist                                 -0.177534
# c_percent muslim                                   -0.341570
# c_percent no central heating                       -0.445406
# c_percent communal heating                         -0.384740
# c_percent TFW less than 2km                        -0.233625
# c_percent 49 or more hours worked                  -0.251545
# c_percent commute on foot                          -0.437600
# c_percent commute metro rail                       -0.450444
# c_percent commute bus                              -0.212462
# c_percent commute bicycle                          -0.508332
# c_percent student moved to address                 -0.322703
# c_percent occupancy rating bedrooms -2             -0.318005
# c_percent occupancy rating bedrooms -1             -0.333175
# c_percent 10 years or more                         -0.378061
# c_percent 2 years or more but less than 5 years    -0.587818
# c_percent 5 years or more but less than 10 years   -0.523660
# c_percent married or in a registered civil part... -0.292020
# c_percent married or in a registered civil part... -0.271597
# c_percent separated but still legally married o... -0.144563
# c_percent divorced or civil partnership dissolv... -0.245002
# c_percent   cannot speak english well              -0.328361
# c_percent   cannot speak english                   -0.283024
# c_percent households deprived in four dimensions   -0.202915

# %%
model
# Out:
# GATv2(
#   (conv1): GATv2Conv(47, 128, heads=1)
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): GATv2Conv(128, 16, heads=1)
#   (bn2): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=16, out_features=1, bias=True)
# )
