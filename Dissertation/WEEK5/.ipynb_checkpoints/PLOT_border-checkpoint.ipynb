# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import numpy as np
from utils import *

# %%
tex_fonts = {
    #source: https://jwalton.info/Embed-Publication-Matplotlib-Latex/
    # Use LaTeX to write all text
    "text.usetex": True,
    "font.family": "serif",
    # Use 10pt font in plots, to match 10pt font in document
    #"axes.labelsize": 10,
    "font.size": 10,
    # Make the legend/label fonts a little smaller
    "legend.fontsize": 8,
    "axes.titlesize": 10,
    "xtick.labelsize": 8,
    "ytick.labelsize": 8,
    'text.latex.preamble': r"\usepackage{amsmath}"
}

# %%
# 读取CSV文件并创建GeoDataFrame
csv_file = 'LondonLSOAs.csv'
gdf = pd.read_csv(csv_file)

# %%
gdf
# Out:
#                        LSOA21NM     centroid_x     centroid_y  \
# 0           City of London 001A  532151.194178  181615.201393
# 1           City of London 001B  532443.686041  181645.724884
# 2           City of London 001C  532207.014825  182030.129598
# 3           City of London 001E  533618.348516  181157.354255
# 4     Barking and Dagenham 016A  544934.369716  184297.546524
# ...                         ...            ...            ...
# 4989           Westminster 019G  527083.282054  180176.729445
# 4990           Westminster 021F  530104.511513  178776.525179
# 4991           Westminster 021G  530005.025734  178506.147240
# 4992           Westminster 023H  528414.134365  178426.896667
# 4993           Westminster 024G  529554.284302  178071.047468
#
#       c_percent asian  c_percent black  c_percent mixed  c_percent white  \
# 0            0.107191         0.007463         0.037992         0.801221
# 1            0.130592         0.007937         0.043290         0.782107
# 2            0.094913         0.034739         0.062655         0.741315
# 3            0.321526         0.108084         0.071753         0.385104
# 4            0.479675         0.108401         0.037940         0.327913
# ...               ...              ...              ...              ...
# 4989         0.209665         0.022214         0.072486         0.621590
# 4990         0.158805         0.066824         0.058176         0.630503
# 4991         0.110107         0.069022         0.105998         0.654889
# 4992         0.180412         0.116409         0.054124         0.560137
# 4993         0.220566         0.022355         0.043716         0.659712
#
#       c_percent sikh  c_percent hindu  c_percent christian  ...  \
# 0           0.000000         0.026441             0.345763  ...
# 1           0.000000         0.015173             0.338150  ...
# 2           0.001860         0.011159             0.340360  ...
# 3           0.000000         0.014519             0.367514  ...
# 4           0.036295         0.056880             0.371614  ...
# ...              ...              ...                  ...  ...
# 4989        0.006233         0.040125             0.419945  ...
# 4990        0.000784         0.019608             0.431373  ...
# 4991        0.001643         0.010682             0.458505  ...
# 4992        0.003002         0.011578             0.433533  ...
# 4993        0.001489         0.018362             0.433747  ...
#
#       e_snow_and_ice  o_diabetes_quantity_per_capita  \
# 0           0.092108                        0.834958
# 1           0.108474                        0.957987
# 2           0.088695                        1.532698
# 3           0.072893                        0.918772
# 4           0.032890                       33.986967
# ...              ...                             ...
# 4989        0.038191                             NaN
# 4990        0.033790                             NaN
# 4991        0.033190                             NaN
# 4992        0.030521                             NaN
# 4993        0.031552                             NaN
#
#       o_opioids_quantity_per_capita  o_OME_per_capita  \
# 0                          0.129840          1.134302
# 1                          0.276066          2.587085
# 2                          0.592661          5.072608
# 3                          0.250619          2.218236
# 4                          4.982723        191.202486
# ...                             ...               ...
# 4989                            NaN               NaN
# 4990                            NaN               NaN
# 4991                            NaN               NaN
# 4992                            NaN               NaN
# 4993                            NaN               NaN
#
#       o_total_quantity_per_capita  o_asthma_quantity_per_capita  \
# 0                        2.626636                      0.139674
# 1                        3.002415                      0.203468
# 2                        3.607429                      0.361956
# 3                        3.205100                      0.359229
# 4                        6.301225                      5.155322
# ...                           ...                           ...
# 4989                          NaN                           NaN
# 4990                          NaN                           NaN
# 4991                          NaN                           NaN
# 4992                          NaN                           NaN
# 4993                          NaN                           NaN
#
#       o_hypertension_quantity_per_capita  o_depression_quantity_per_capita  \
# 0                               1.047404                          0.349620
# 1                               1.341916                          0.514907
# 2                               2.189897                          0.979002
# 3                               1.447732                          1.559360
# 4                              36.456869                          7.325503
# ...                                  ...                               ...
# 4989                                 NaN                               NaN
# 4990                                 NaN                               NaN
# 4991                                 NaN                               NaN
# 4992                                 NaN                               NaN
# 4993                                 NaN                               NaN
#
#       o_anxiety_quantity_per_capita  \
# 0                          0.478279
# 1                          0.757793
# 2                          1.391262
# 3                          1.842563
# 4                         11.725343
# ...                             ...
# 4989                            NaN
# 4990                            NaN
# 4991                            NaN
# 4992                            NaN
# 4993                            NaN
#
#                                                geometry
# 0     POLYGON ((532105.312 182010.573999999, 532162....
# 1     POLYGON ((532634.497 181926.016000001, 532619....
# 2     POLYGON ((532135.1382 182198.130999999, 532158...
# 3     POLYGON ((533808.0176 180767.7744, 533649.037 ...
# 4     POLYGON ((545122.049 184314.931, 545271.8494 1...
# ...                                                 ...
# 4989  POLYGON ((528427.719 180115.108999999, 528410....
# 4990  POLYGON ((530276.4648 178962.7006, 530238.78 1...
# 4991  POLYGON ((529867.785 178609.306, 529892.537 17...
# 4992  POLYGON ((528674.775 178693.078400001, 528612....
# 4993  POLYGON ((529651.8082 178210.674799999, 529692...
#
# [4994 rows x 167 columns]

# %%
def plot_variable_v2(gdf, variable, variable_name):

    if variable.startswith('e'):
        colormap = colors.LinearSegmentedColormap.from_list('', ['#ffffff', '#c27ba0'])
    elif variable.startswith('o'):
        colormap = colors.LinearSegmentedColormap.from_list('', ['#ffffff', '#6d9eeb'])
    elif variable.startswith('c'):
        colormap = colors.LinearSegmentedColormap.from_list('', ['#ffffff', '#008080'])
    else:
        colormap = 'coolwarm'

    # Parameters to display missing data in black
    missing_data_color = {
        'color': 'black',
        # 'color':'#808080',
        # 'edgecolor': 'black',
        # 'hatch': '///',  # this is optional, if you'd like a hatch pattern for missing data
        'label': 'Missing Data'
    }

    # Plotting the GeoPandas DataFrame
    ax = gdf.plot(column=variable, legend=True, figsize=(15, 10), cmap=colormap, missing_kwds=missing_data_color)

    # Remove the axes
    plt.axis('off')

    # Customize the legend font size
    # Get the color bar object
    cax = plt.gcf().axes[-1]

    # Customize the color bar font size
    cax.tick_params(labelsize=33)

    # Title
    plt.title(variable_name, fontsize=44)

    return plt

# %%
variable = 'c_percent asian'
variable_name = 'Pre'
plot_variable_v2(gdf, variable, variable_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 3
#       1 variable = 'c_percent asian'
#       2 variable_name = 'Pre'
# ----> 3 plot_variable_v2(gdf, variable, variable_name)
#
# Cell In[10], line 25, in plot_variable_v2(gdf, variable, variable_name)
#      22 base = gdf[gdf[variable] != -9999].plot(column=variable, legend=True, figsize=(15, 10), cmap=colormap)
#      24 # Overlay missing data with a specific color
# ---> 25 gdf[gdf[variable] == -9999].plot(ax=base, color=missing_data_color, edgecolor='black', hatch='///', label='Missing Data')
#      27 # Remove the axes
#      28 plt.axis('off')
#
# File ~\anaconda3\envs\envGEOG0051\Lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\envs\envGEOG0051\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\envs\envGEOG0051\Lib\site-packages\pandas\plotting\_matplotlib\core.py:453, in MPLPlot.generate(self)
#     451 self._compute_plot_data()
#     452 self._setup_subplots()
# --> 453 self._make_plot()
#     454 self._add_table()
#     455 self._make_legend()
#
# File ~\anaconda3\envs\envGEOG0051\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1392, in LinePlot._make_plot(self)
#    1389 label = self._mark_right_label(label, index=i)
#    1390 kwds["label"] = label
# -> 1392 newlines = plotf(
#    1393     ax,
#    1394     x,
#    1395     y,
#    1396     style=style,
#    1397     column_num=i,
#    1398     stacking_id=stacking_id,
#    1399     is_errorbar=is_errorbar,
#    1400     **kwds,
#    1401 )
#    1402 self._append_legend_handles_labels(newlines[0], label)
#    1404 if self._is_ts_plot():
#    1405     # reset of xlim should be used for ts data
#    1406     # TODO: GH28021, should find a way to change view limit on xaxis
#
# File ~\anaconda3\envs\envGEOG0051\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1421, in LinePlot._plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#    1419     cls._initialize_stacker(ax, stacking_id, len(y))
#    1420 y_values = cls._get_stacked_values(ax, stacking_id, y, kwds["label"])
# -> 1421 lines = MPLPlot._plot(ax, x, y_values, style=style, **kwds)
#    1422 cls._update_stacker(ax, stacking_id, y)
#    1423 return lines
#
# File ~\anaconda3\envs\envGEOG0051\Lib\site-packages\pandas\plotting\_matplotlib\converter.py:97, in register_pandas_matplotlib_converters.<locals>.wrapper(*args, **kwargs)
#      94 @functools.wraps(func)
#      95 def wrapper(*args, **kwargs):
#      96     with pandas_converters():
# ---> 97         return func(*args, **kwargs)
#
# File ~\anaconda3\envs\envGEOG0051\Lib\site-packages\pandas\plotting\_matplotlib\core.py:891, in MPLPlot._plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     888 else:
#     889     # prevent style kwarg from going to errorbar, where it is unsupported
#     890     args = (x, y, style) if style is not None else (x, y)
# --> 891     return ax.plot(*args, **kwds)
#
# File ~\anaconda3\envs\envGEOG0051\Lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File ~\anaconda3\envs\envGEOG0051\Lib\site-packages\matplotlib\axes\_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\anaconda3\envs\envGEOG0051\Lib\site-packages\matplotlib\axes\_base.py:539, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     537     return list(result)
#     538 else:
# --> 539     return [l[0] for l in result]
#
# File ~\anaconda3\envs\envGEOG0051\Lib\site-packages\matplotlib\axes\_base.py:539, in <listcomp>(.0)
#     537     return list(result)
#     538 else:
# --> 539     return [l[0] for l in result]
#
# File ~\anaconda3\envs\envGEOG0051\Lib\site-packages\matplotlib\axes\_base.py:532, in <genexpr>(.0)
#     529 else:
#     530     labels = [label] * n_datasets
# --> 532 result = (make_artist(axes, x[:, j % ncx], y[:, j % ncy], kw,
#     533                       {**kwargs, 'label': label})
#     534           for j, label in enumerate(labels))
#     536 if return_kwargs:
#     537     return list(result)
#
# File ~\anaconda3\envs\envGEOG0051\Lib\site-packages\matplotlib\axes\_base.py:346, in _process_plot_var_args._makeline(self, axes, x, y, kw, kwargs)
#     344 default_dict = self._getdefaults(set(), kw)
#     345 self._setdefaults(default_dict, kw)
# --> 346 seg = mlines.Line2D(x, y, **kw)
#     347 return seg, kw
#
# File ~\anaconda3\envs\envGEOG0051\Lib\site-packages\matplotlib\lines.py:407, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     403 self.set_markeredgewidth(markeredgewidth)
#     405 # update kwargs before updating data to give the caller a
#     406 # chance to init axes (and hence unit support)
# --> 407 self._internal_update(kwargs)
#     408 self.pickradius = pickradius
#     409 self.ind_offset = 0
#
# File ~\anaconda3\envs\envGEOG0051\Lib\site-packages\matplotlib\artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File ~\anaconda3\envs\envGEOG0051\Lib\site-packages\matplotlib\artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: Line2D.set() got an unexpected keyword argument 'edgecolor'
